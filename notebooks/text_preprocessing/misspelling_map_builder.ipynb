# %% [markdown]
# # MisSpelling Map Builder
# This notebook is aimed to fix upfront misspelled words from the training text. It proceeds along below priority order:
# * identify firstly all unknown/out of vocabulary words
# * among previously identified unknown term, try to suggest a fix based on the custom/medical named entity we built specifically
#   * drug name
#   * active ingredient
# * in a second time, try to suggest a fix based on the general thesaurus
#
# We favor first domain specific named entities because their spelling is pretty particular.
#
# It generates 3 csv files into staging_data folder, defining the map from the misspelled word to its fix suggestion:
# * mispelled_drug_names.csv
# * mispelled_ingredient_names.csv
# * mispelled_general_names.csv
#
#
# The domain specific named entity correction is inspired from https://norvig.com/spell-correct.html souce code.
# It relies on the Levenshtein word distance principle and takes adavantge of the word frequency (learnt from large corpus) to compute the likehood of the word suggestion.
#
# A threshold on the Levenshtein distance needs to be defined to accept the correction suggestion: I prefer to compute the ratio between Levenshtein disance over the word length as this indicator is more significant to identify unintentional spelling incorrectness.
#
# For the general purpose vocabulary, I make use of the **SpellChecker** package which comes with french resources.

# %% [markdown]
# ## Identify out of vocabulary words
#
# Unknown words are relative to a dictionary. Which dictionary to consider?
# In fact, for DL pipeline, we make use of pretrained embedding model (fasttest) which is badly resilient in case of mispelled word. To prevent from falling into such situation, we will consider the fasttext vocabulary as the reference to determine if a word is identified as out of vocabulary
# There 's a dedidated Jupyter notebook [notebook](outofvocabulary_identifier.ipynb) which generates a csv file containing the unknown word list [file](../../data/staging_data/outofvocab_words.txt)

# %% [markdown]
# ## Custom spelling corrector

# %%
# custom code to fix domain specific words which are incorrectedly spelled
# inspiration source: https://norvig.com/spell-correct.html
import Levenshtein
import csv
import re
from collections import Counter


def words(text):
    return re.findall(r'\w+', text.lower())


def getCandidates(word, refDictionary): 
    "generate possible spelling corrections for word"
    return (known([word], refDictionary) or known(edits1(word), refDictionary) or known(edits2(word), refDictionary) or [word])

def known(words, refDictionary): 
    "the subset of `words` that appear in the dictionary."
    return set(w for w in words if w in refDictionary)

def edits1(word):
    "all edits that are one edit away from `word`"
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "all edits that are two edits away from `word`"
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

def fixWord(word, refDictionary): 
    candidates = getCandidates(word, refDictionary)
    minDist = 10000.
    bestCandidate = None
    bestDistance = None
    for candidate in candidates:
        dist = Levenshtein.distance(candidate, word) / len(word)
        if dist < minDist:
            bestCandidate = candidate
            bestDistance = dist
            minDist = dist
    return (bestCandidate, bestDistance)


def buildFixMap(words, refDictionary, distanceThreshold, exclusionList, fileName):      
    misSpelledMap = {}
    for word in words:
        fixedWord, distance = fixWord(word, refDictionary)
        if fixedWord != word:            
            if not exclusionList is None and word in exclusionList:
                print("{0} is already handled".format(word))
                continue
            acceptFix = distance <= distanceThreshold
            flag = "OK" if acceptFix else "KO"
            print("{3}  {0} => {1} with dist={2:.4f}".format(word, fixedWord, distance, flag))
            if acceptFix:
                misSpelledMap[word] = fixedWord
    writer = csv.writer(open(fileName, "w"), lineterminator='\r')
    for key, val in misSpelledMap.items():
        writer.writerow([key, val])
    return misSpelledMap

# %% [markdown]
# # Drug name

# %%
with open('../../data/staging_data/fasttext_outofvocab_words.txt',encoding='utf-8') as f:
    unknownWords = f.read().splitlines()
len(unknownWords)
# Out:
# 2108

# %%
drugNames = Counter(words(open('../../data/staging_data/drug_names.txt').read()))
misSpelledDrugMap = buildFixMap(unknownWords, drugNames, 0.25, None, "../../data/staging_data/mispelled_drug_names.csv")
# Out:
# OK  cérazette => cerazette with dist=0.1111
# OK  adépal => adepal with dist=0.1667
# OK  sterilet => sterilene with dist=0.2500
# OK  lutéran => luteran with dist=0.1429
# OK  cycléane => cycleane with dist=0.1250
# KO  gygy => gyno with dist=0.5000
# OK  lyoc => lyo with dist=0.2500
# OK  seroquel => xeroquel with dist=0.1250
# OK  triafémi => triafemi with dist=0.1250
# OK  lutényl => lutenyl with dist=0.1429
# OK  désobel => desobel with dist=0.1429
# OK  déroxat => deroxat with dist=0.1429
# KO  dexorat => deroxat with dist=0.2857
# KO  qu’il => quixil with dist=0.4000
# KO  anxiete => anxietum with dist=0.2857
# OK  gelsenium => gelsemium with dist=0.1111
# KO  apetit => apatite with dist=0.3333
# OK  séropram => seropram with dist=0.1250
# OK  prévenar => prevenar with dist=0.1250
# OK  lévothyrox => levothyrox with dist=0.1000
# OK  calcibronate => calcibronat with dist=0.0833
# OK  seropam => seropram with dist=0.1429
# OK  miréna => mirena with dist=0.1667
# OK  bétaserc => betaserc with dist=0.1250
# OK  dépamide => depamide with dist=0.1250
# OK  androcure => androcur with dist=0.1111
# OK  holgyème => holgyeme with dist=0.1250
# OK  efflexor => effexor with dist=0.1250
# OK  sertaline => sertraline with dist=0.1111
# OK  strésam => stresam with dist=0.1429
# OK  corticoide => coricide with dist=0.2000
# OK  infarix => infanrix with dist=0.1429
# KO  c'est => cilest with dist=0.4000
# OK  lisanxia => lysanxia with dist=0.1250
# OK  xénical => xenical with dist=0.1429
# OK  orgastoro => ogastoro with dist=0.1111
# OK  remicad => remicade with dist=0.1429
# OK  vogalène => vogalene with dist=0.1250
# OK  téralithe => teralithe with dist=0.1111
# OK  efexor => effexor with dist=0.1667
# OK  temestat => temesta with dist=0.1250
# OK  lysopaine => lysocline with dist=0.2222
# OK  lexomyl => lexomil with dist=0.1429
# OK  stédiril => stediril with dist=0.1250
# OK  spéciafoldine => speciafoldine with dist=0.0769
# OK  monéva => moneva with dist=0.1667
# OK  équanil => equanil with dist=0.1429
# KO  vacin => cacit with dist=0.4000
# OK  trinordiole => trinordiol with dist=0.0909
# OK  luthényl => lutenyl with dist=0.2500
# OK  tégrétol => tegretol with dist=0.2500
# OK  phosphorica => phosphoricum with dist=0.1818
# OK  méningitec => meningitec with dist=0.1000
# OK  minidrill => minidril with dist=0.1111
# OK  débridat => debridat with dist=0.1250
# OK  efféralgant => efferalgan with dist=0.1818
# OK  hydroxyquine => hydroxyzine with dist=0.1667
# OK  azithromycin => azithromycine with dist=0.0833
# OK  arkogellules => arkogelules with dist=0.0833
# OK  sporténine => sportenine with dist=0.1000
# OK  théralène => theralene with dist=0.2222
# OK  evépar => evepar with dist=0.1667
# OK  dépakote => depakote with dist=0.1250
# OK  léxomil => lexomil with dist=0.1429
# OK  arpagophitum => harpagophytum with dist=0.1667
# OK  amoxicillin => amoxicilline with dist=0.0909
# OK  rocéphine => rocephine with dist=0.1111
# OK  amoxiciline => amoxicilline with dist=0.0909
# OK  décontractyl => decontractyl with dist=0.0833
# KO  repri => reopro with dist=0.4000
# KO  'il => cis with dist=0.6667
# OK  lysenxia => lysanxia with dist=0.1250
# OK  norlévo => norlevo with dist=0.1429
# KO  séropam => seropram with dist=0.2857
# OK  locoïd => locoid with dist=0.1667
# OK  miness => minesse with dist=0.1667
# OK  meningite => meningitec with dist=0.1111
# OK  biceptine => biseptine with dist=0.1111
# OK  fortimel => fortigel with dist=0.1250
# OK  roacutane => roaccutane with dist=0.1111
# KO  isoror => isobar with dist=0.3333
# OK  stillnox => stilnox with dist=0.1250
# KO  monovax => monoox with dist=0.2857
# OK  luthenyl => lutenyl with dist=0.1250
# OK  segement => serevent with dist=0.2500
# OK  trimordiol => trinordiol with dist=0.1000
# KO  anxieté => anxietum with dist=0.2857
# OK  poralamine => polaramine with dist=0.2000
# KO  dapis => dakin with dist=0.4000
# KO  desyrel => desobel with dist=0.2857
# OK  yasminelle => jasminelle with dist=0.1000
# OK  alvocardyl => avlocardyl with dist=0.2000
# OK  stinox => stilnox with dist=0.1667
# OK  efféralgan => efferalgan with dist=0.1000
# OK  nuraving => nuvaring with dist=0.2500
# KO  les'il => lectil with dist=0.3333
# OK  cerrazette => cerazette with dist=0.1000
# OK  priopix => priorix with dist=0.1429
# OK  tardyféron => tardyferon with dist=0.1000
# OK  néoral => neoral with dist=0.1667
# KO  folic => mobic with dist=0.4000
# OK  solumédrol => solumedrol with dist=0.1000
# KO  genyco => glyco with dist=0.3333
# OK  notran => noctran with dist=0.1667
# OK  kardégic => kardegic with dist=0.1250
# KO  qql => nol with dist=0.6667
# OK  pentacoq => pentacis with dist=0.2500
# OK  gardasyl => gardasil with dist=0.1250
# OK  hydorcortisone => hydrocortisone with dist=0.1429
# OK  sterilets => sterilene with dist=0.2222
# OK  minoxydil => minoxidil with dist=0.1111
# OK  grifonia => agrimonia with dist=0.2500
# OK  zythromax => zithromax with dist=0.1111
# OK  varoline => varnoline with dist=0.1250
# OK  viscéralgine => visceralgine with dist=0.0833
# OK  abilyfy => abilify with dist=0.1429
# OK  clarytine => clarityne with dist=0.2222
# OK  dolipranes => doliprane with dist=0.1000
# OK  immurel => imurel with dist=0.1429
# OK  stomectol => stromectol with dist=0.1111
# KO  apétit => apatite with dist=0.3333
# KO  pilul => pilo with dist=0.4000
# OK  hypericine => hyperamine with dist=0.2000
# OK  risperal => risperdal with dist=0.1250
# OK  relaxis => revaxis with dist=0.1429
# OK  ménopur => menopur with dist=0.1429
# OK  cyclean => cycleane with dist=0.1429
# OK  carbonica => carbonicum with dist=0.2222
# OK  abilifly => abilify with dist=0.1250
# OK  curacnée => curacne with dist=0.1250
# OK  minidrile => minidril with dist=0.1111
# OK  périactine => periactine with dist=0.1000
# OK  tetrazepan => tetrazepam with dist=0.1000
# OK  progesteronum => progesterone with dist=0.1538
# OK  séroquel => xeroquel with dist=0.2500
# OK  gelsémium => gelsemium with dist=0.1111
# OK  strepsil => strepsils with dist=0.1250
# OK  prevnar => prevenar with dist=0.1429
# OK  tetramysal => tetralysal with dist=0.1000
# OK  bexero => bexsero with dist=0.1667
# KO  auco => maco with dist=0.5000
# OK  microvial => microval with dist=0.1111
# OK  xanac => xanax with dist=0.2000
# OK  antibios => antibio with dist=0.1250
# OK  bromazepan => bromazepam with dist=0.1000
# OK  alprozolam => alprazolam with dist=0.1000
# KO  liloo => pilo with dist=0.4000
# OK  euphitose => euphytose with dist=0.1111
# KO  exorex => eprex with dist=0.3333
# OK  jasminielle => jasminelle with dist=0.0909
# KO  hctz => act with dist=0.5000
# OK  aturgil => aturgyl with dist=0.1429
# OK  ignitia => ignatia with dist=0.1429
# OK  hélicobacter => helicobacter with dist=0.0833
# KO  pylorii => zyloric with dist=0.2857
# OK  amoxyciline => amoxicilline with dist=0.1818
# OK  steriler => sterilene with dist=0.2500
# OK  prosac => prozac with dist=0.1667
# OK  celestène => celestene with dist=0.1111
# OK  amoxilline => amoxicilline with dist=0.2000
# OK  trinordyol => trinordiol with dist=0.1000
# OK  chlormadione => chlormadinone with dist=0.0833
# KO  m'a => uva with dist=0.6667
# OK  spotog => spotof with dist=0.1667
# OK  curacné => curacne with dist=0.1429
# OK  kétoderm => ketoderm with dist=0.1250
# OK  dtpe => dtpa with dist=0.2500
# KO  urtile => urtica with dist=0.3333
# KO  qiue => true with dist=0.5000
# OK  ténoretic => tenoretic with dist=0.1111
# OK  stérogyl => sterogyl with dist=0.1250
# KO  sillice => silicea with dist=0.2857
# OK  tricelest => tricilest with dist=0.1111
# OK  naxproxen => naproxene with dist=0.2222
# OK  ethinilestradiol => ethinylestradiol with dist=0.0625
# KO  veroa => vedrop with dist=0.4000
# OK  célestene => celestene with dist=0.1111
# OK  orgametil => orgametril with dist=0.1111
# OK  kardefic => kardegic with dist=0.1250
# OK  extranaze => extranase with dist=0.1111
# OK  avocardil => avlocardyl with dist=0.2222
# KO  rappor => apsor with dist=0.3333
# OK  gardazil => gardasil with dist=0.1250
# KO  èpas => upsa with dist=0.7500
# OK  triafermi => triafemi with dist=0.1111
# KO  ultram => ostram with dist=0.3333
# KO  strees => strefen with dist=0.3333
# OK  detoxat => deroxat with dist=0.1429
# KO  püis => cis with dist=0.5000
# OK  optidtil => optidril with dist=0.1250
# KO  prennne => rennie with dist=0.2857
# KO  eucal => nucala with dist=0.4000
# KO  citr => cis with dist=0.5000
# KO  soprol => mopral with dist=0.3333
# KO  qui'l => quixil with dist=0.4000
# OK  optimisette => optimizette with dist=0.0909
# KO  ethpo => ether with dist=0.4000
# OK  gelsemiuim => gelsemium with dist=0.1000
# KO  flushs => flucis with dist=0.3333
# OK  déturgylone => deturgylone with dist=0.0909
# OK  gerdazil => gardasil with dist=0.2500
# OK  floxifral => floxyfral with dist=0.1111
# OK  proitrine => prostine with dist=0.2222
# OK  voltaréne => voltarene with dist=0.1111
# OK  andorcur => androcur with dist=0.2500
# KO  ingatia => ignatia with dist=0.2857
# OK  mynocicline => minocycline with dist=0.1818
# OK  naturland => natulan with dist=0.2222
# KO  alyna => alka with dist=0.4000
# OK  dolyprane => doliprane with dist=0.1111
# OK  cytotek => cytotec with dist=0.1429
# OK  ludeale => ludeal with dist=0.1429
# KO  gracial => fractal with dist=0.2857
# KO  ado' => aloe with dist=0.5000
# OK  oeuphytoses => euphytose with dist=0.1818
# OK  seoplex => seroplex with dist=0.1429
# OK  floradil => foradil with dist=0.1250
# OK  alverine => elvorine with dist=0.2500
# KO  nizoral => neoral with dist=0.2857
# OK  kethoderm => ketoderm with dist=0.1111
# KO  gynelle => gydrelle with dist=0.2857
# OK  urosuphon => urosiphon with dist=0.1111
# OK  physiogyne => physiogine with dist=0.1000
# OK  trophicrème => trophicreme with dist=0.0909
# OK  paracétamole => paracetamol with dist=0.1667
# KO  welada => xeloda with dist=0.3333
# OK  ymbicort => symbicort with dist=0.1250
# OK  provannes => provames with dist=0.2222
# OK  claritine => clarityne with dist=0.1111
# OK  modlodal => modiodal with dist=0.1250
# KO  codion => eudion with dist=0.3333
# OK  orbénine => orbenine with dist=0.1250
# OK  colposeptine… => colposeptine with dist=0.0769
# OK  attarax => atarax with dist=0.1429
# KO  hcz => hec with dist=0.6667
# OK  lorezepam => lorazepam with dist=0.1111
# OK  callendula => calendula with dist=0.1000
# OK  magnogène => magnogene with dist=0.1111
# KO  perléne => perfane with dist=0.2857
# OK  tronordiol => trinordiol with dist=0.1000
# OK  pontalgine => prontalgine with dist=0.1000
# OK  immovane => imovane with dist=0.1250
# OK  josacyne => josacine with dist=0.1250
# OK  caseine => cafeine with dist=0.1429
# KO  dtvax => dtpa with dist=0.4000
# KO  concer => cooper with dist=0.3333
# OK  eucaliptine => eucalyptine with dist=0.0909
# OK  leffexor => effexor with dist=0.1250
# OK  anserine => mianserine with dist=0.2500
# KO  gonfe => gonal with dist=0.4000
# KO  faot => tot with dist=0.5000
# OK  jesminelle => jasminelle with dist=0.1000
# OK  mifégyne => mifegyne with dist=0.1250
# OK  europhytose => euphytose with dist=0.1818
# KO  anxios => angiox with dist=0.3333
# OK  bélara => belara with dist=0.1667
# KO  qi'il => quixil with dist=0.4000
# OK  mométasone => mometasone with dist=0.1000
# KO  d'ou => dio with dist=0.5000
# OK  lozazepam => lorazepam with dist=0.1111
# OK  carbopol => carbophos with dist=0.2500
# KO  tolere => polery with dist=0.3333
# OK  spiromax => epitomax with dist=0.2500
# OK  lixanxia => lysanxia with dist=0.2500
# OK  transpeg => transipeg with dist=0.1250
# OK  ibiprofene => ibuprofene with dist=0.1000
# OK  ponstil => ponstyl with dist=0.1429
# OK  typhum => typhim with dist=0.1667
# KO  savir => salix with dist=0.4000
# OK  helicobactère => helicobacter with dist=0.1538
# KO  'un => nux with dist=0.6667
# OK  levocétirizine => levocetirizine with dist=0.0714
# KO  plusa => upsa with dist=0.6000
# OK  panthoprazole => pantoprazole with dist=0.0769
# OK  lutenil => lutenyl with dist=0.1429
# KO  éatit => cacit with dist=0.4000
# OK  holgyome => holgyeme with dist=0.1250
# OK  phaéva => phaeva with dist=0.1667
# KO  jorai => zorac with dist=0.4000
# OK  hémoclar => hemoclar with dist=0.1250
# OK  boostrixterra => boostrixtetra with dist=0.0769
# OK  gardasile => gardasil with dist=0.1111
# OK  effeor => effexor with dist=0.1667
# OK  granion => granions with dist=0.1429
# OK  vertrige => vectrine with dist=0.2500
# OK  endrocure => androcur with dist=0.2222
# OK  cefpodoxine => cefpodoxime with dist=0.0909
# OK  lonten => lonoten with dist=0.1667
# KO  jpren => eprex with dist=0.4000
# OK  ibuprophene => ibuprofene with dist=0.1818
# KO  arvara => aldara with dist=0.3333
# OK  létrozole => letrozole with dist=0.1111
# OK  zoély => zoely with dist=0.2000
# OK  nasocort => nasacort with dist=0.1250
# OK  skénan => skenan with dist=0.1667
# OK  levthyroxine => levothyroxine with dist=0.0833
# OK  betaméthasone => betamethasone with dist=0.0769
# OK  mitélase => mytelase with dist=0.2500
# KO  solager => salagen with dist=0.2857
# OK  trinardiol => trinordiol with dist=0.1000
# OK  tétravac => tetravac with dist=0.1250
# OK  silecea => silicea with dist=0.1429
# OK  minazol => monazol with dist=0.1429
# OK  prothuiaden => prothiaden with dist=0.0909
# OK  tinordiol => trinordiol with dist=0.1111
# OK  luysanxia => lysanxia with dist=0.1111
# OK  milepertuis => millepertuis with dist=0.0909
# KO  y'a => uva with dist=0.6667
# KO  norflex => nureflex with dist=0.2857
# OK  uvédose => uvedose with dist=0.1429
# OK  gestodène => gestodene with dist=0.1111
# KO  levre => evra with dist=0.4000
# KO  'ai => yaz with dist=0.6667
# OK  surgestonne => surgestone with dist=0.0909
# KO  opèrer => optrex with dist=0.3333
# KO  jouire => josir with dist=0.3333
# KO  alprax => atarax with dist=0.3333
# OK  jaminelle => jasminelle with dist=0.1111
# OK  terginan => tergynan with dist=0.1250
# OK  norofloxacine => norfloxacine with dist=0.0769
# OK  hypérium => hyperium with dist=0.1250
# OK  ludoz => lodoz with dist=0.2000
# KO  èa => uva with dist=1.0000
# OK  médrol => medrol with dist=0.1667
# OK  micoster => mycoster with dist=0.1250
# OK  noctram => noctran with dist=0.1429
# OK  ténormine => tenormine with dist=0.1111
# OK  effecor => effexor with dist=0.1429
# KO  lutéal => ludeal with dist=0.3333
# OK  minrena => mirena with dist=0.1429
# OK  hélicidine => helicidine with dist=0.1000
# OK  norelevo => norlevo with dist=0.1250
# OK  duphastons => duphaston with dist=0.1000
# OK  leloo => leeloo with dist=0.2000
# OK  aripiprazol => aripiprazole with dist=0.0909
# OK  orgamétril => orgametril with dist=0.1000
# OK  leprozol => letrozole with dist=0.2500
# OK  microvla => microval with dist=0.2500
# OK  creatine => covatine with dist=0.2500
# OK  cyprotèrone => cyproterone with dist=0.0909
# OK  multibolic => multibic with dist=0.2000
# KO  ovarine => savarine with dist=0.2857
# OK  omeprazol => omeprazole with dist=0.1111
# OK  cepodoxime => cefpodoxime with dist=0.1000
# OK  ignata => ignatia with dist=0.1667
# OK  efferlgan => efferalgan with dist=0.1111
# OK  calcaréa => calcarea with dist=0.1250
# OK  cortrancyl => cortancyl with dist=0.1000
# OK  lovénox => lovenox with dist=0.1429
# OK  lamictale => lamictal with dist=0.1111
# OK  theralith => teralithe with dist=0.2222
# OK  mlillepertuis => millepertuis with dist=0.0769
# OK  ceterizine => cetirizine with dist=0.1000
# OK  micycline => minocycline with dist=0.2222
# OK  infranrix => infanrix with dist=0.1111
# OK  ketoderme => ketoderm with dist=0.1111
# OK  lithoderm => lithioderm with dist=0.1111
# OK  chammilla => chamomilla with dist=0.1111
# OK  provame => provames with dist=0.1429
# OK  muriacum => muriaticum with dist=0.2500
# KO  beance => ibrance with dist=0.3333
# KO  jsais => thais with dist=0.4000
# OK  soprolol => bisoprolol with dist=0.2500
# OK  daphalgan => dafalgan with dist=0.2222
# KO  synecod => synercid with dist=0.2857
# OK  tujeo => toujeo with dist=0.2000
# OK  primpera => primperan with dist=0.1250
# KO  'eau => keal with dist=0.5000
# OK  mébéverine => mebeverine with dist=0.2000
# KO  clozan => flolan with dist=0.3333
# OK  valdonxan => valdoxan with dist=0.1111
# KO  pilue => pilo with dist=0.4000
# OK  vasorbal => vasobral with dist=0.2500
# OK  zyprex => zyprexa with dist=0.1667
# OK  monotest => monosept with dist=0.2500
# OK  andocur => androcur with dist=0.1429
# OK  protegés => protelos with dist=0.2500
# KO  abcés => abies with dist=0.4000
# OK  endotélon => endotelon with dist=0.1111
# KO  oomg => oromag with dist=0.5000
# OK  mépronizine => mepronizine with dist=0.0909
# OK  prozas => prozac with dist=0.1667
# KO  ativan => atrican with dist=0.3333
# OK  rhinofluimicil => rhinofluimucil with dist=0.0714
# OK  cardenciel => cardensiel with dist=0.1000
# OK  milleperthuis => millepertuis with dist=0.0769
# KO  execive => exocine with dist=0.2857
# KO  kelkun => selsun with dist=0.3333
# OK  rivortil => rivotril with dist=0.2500
# OK  oxomémazine => oxomemazine with dist=0.0909
# OK  zyma => zymad with dist=0.2500
# OK  millerpertuis => millepertuis with dist=0.0769
# OK  quétiapin => quetiapine with dist=0.2222
# OK  lysensia => lysanxia with dist=0.2500
# OK  sertalia => smectalia with dist=0.2500
# OK  nourrison => normison with dist=0.2222
# KO  c’est => cilest with dist=0.4000
# OK  stederil => stediril with dist=0.1250
# OK  evapar => evepar with dist=0.1667
# KO  benivit => recivit with dist=0.2857
# KO  gonglé => gonal with dist=0.3333
# KO  normix => omix with dist=0.3333
# OK  roxytromycine => roxithromycine with dist=0.1538
# OK  trophygil => trophigil with dist=0.1111
# OK  trophigill => trophigil with dist=0.1000
# OK  tridnordiol => trinordiol with dist=0.0909
# OK  nocerton => nocertone with dist=0.1250
# OK  engérix => engerix with dist=0.1429
# OK  mienesse => minesse with dist=0.1250
# OK  caffea => coffea with dist=0.1667
# OK  zirtec => zyrtec with dist=0.1667
# OK  florygynal => florgynal with dist=0.1000
# KO  noctifs => noctium with dist=0.2857
# OK  feldène => feldene with dist=0.1429
# KO  immovan => imovane with dist=0.2857
# OK  perlodel => parlodel with dist=0.1250
# OK  oeuphytose => euphytose with dist=0.1000
# OK  chamomilia => chamomilla with dist=0.1000
# OK  nomégestrol => nomegestrol with dist=0.0909
# OK  effizin => effizinc with dist=0.1429
# OK  tétralysal => tetralysal with dist=0.1000
# OK  soluprede => solupred with dist=0.1111
# OK  harpagopytum => harpagophytum with dist=0.0833
# KO  medcin => mecir with dist=0.3333
# OK  coaaprovel => coaprovel with dist=0.1000
# OK  décapeptyl => decapeptyl with dist=0.1000
# OK  lacmital => lamictal with dist=0.2500
# OK  arpagophytum => harpagophytum with dist=0.0833
# OK  paraxetine => paroxetine with dist=0.1000
# OK  metfomine => metformine with dist=0.1111
# OK  rodogil => rodogyl with dist=0.1429
# KO  revamil => revatio with dist=0.2857
# OK  dopalgic => topalgic with dist=0.1250
# OK  ethynilestradiol => ethinylestradiol with dist=0.1250
# OK  minese => minesse with dist=0.1667
# KO  jarsin => carlin with dist=0.3333
# OK  cymblalta => cymbalta with dist=0.1111
# OK  exeplion => xeplion with dist=0.1250
# OK  trynordiol => trinordiol with dist=0.1000
# OK  hypéricum => hypericum with dist=0.1111
# KO  nitr => nati with dist=0.5000
# OK  differin => differine with dist=0.1250
# KO  vasastrel => vastarel with dist=0.3333
# OK  birodrogyl => birodogyl with dist=0.1000
# OK  amiodorane => amiodarone with dist=0.2000
# OK  cémaflavone => cemaflavone with dist=0.0909
# KO  adépale => adepal with dist=0.2857
# OK  defalgan => dafalgan with dist=0.1250
# OK  weroquel => xeroquel with dist=0.1250
# OK  bisprolol => bisoprolol with dist=0.1111
# OK  synéedil => synedil with dist=0.1250
# OK  anxieter => anxietum with dist=0.2500
# KO  môi => ammi with dist=0.6667
# KO  mèrci => merck with dist=0.4000
# OK  chlomadinone => chlormadinone with dist=0.0833
# OK  cafeiné => cafeine with dist=0.1429
# KO  ginéco => ginkgo with dist=0.3333
# OK  tranxènes => tranxene with dist=0.2222
# KO  nomal => inomax with dist=0.4000
# OK  desorel => desobel with dist=0.1429
# OK  follique => folique with dist=0.1250
# KO  prisle => prialt with dist=0.3333
# KO  bicar => icaz with dist=0.4000
# OK  célestamine => celestamine with dist=0.0909
# OK  lisopaine => lidocaine with dist=0.2222
# KO  bustar => justor with dist=0.3333
# OK  dolirhum => dolirhume with dist=0.1250
# OK  dupahaston => duphaston with dist=0.1000
# KO  gényco => glyco with dist=0.3333
# OK  thyrosine => thyroxine with dist=0.1111
# OK  surgeston => surgestone with dist=0.1111
# OK  eméthotrexate => methotrexate with dist=0.1538
# OK  luteny => lutenyl with dist=0.1667
# OK  témestat => temesta with dist=0.2500
# OK  purinéthol => purinethol with dist=0.1000
# OK  picroval => microval with dist=0.1250
# KO  esoprex => eprex with dist=0.2857
# OK  pantoprazol => pantoprazole with dist=0.0909
# OK  leelou => leeloo with dist=0.1667
# OK  allergenes => stallergenes with dist=0.2000
# OK  mnidril => minidril with dist=0.1429
# OK  diazepan => diazepam with dist=0.1250
# OK  metformin => metformine with dist=0.1111
# OK  monazole => monazol with dist=0.1250
# OK  gynergène => gynergene with dist=0.1111
# OK  seroplexe => seroplex with dist=0.1111
# KO  dailygé => daily with dist=0.2857
# OK  saltrate => caltrate with dist=0.1250
# KO  aïh => act with dist=0.6667
# OK  gyné => gyno with dist=0.2500
# KO  râter => peter with dist=0.4000
# OK  dafalgans => dafalgan with dist=0.1111
# KO  triofan => tiorfan with dist=0.2857
# OK  rispéral => risperdal with dist=0.2500
# OK  phamatex => pharmatex with dist=0.1250
# OK  pevary => pevaryl with dist=0.1667
# OK  sollian => solian with dist=0.1429
# OK  léponex => leponex with dist=0.1429
# OK  diprostène => diprostene with dist=0.1000
# KO  rrien => urion with dist=0.4000
# OK  mabthéra => mabthera with dist=0.1250
# OK  serotonine => levotonine with dist=0.2000
# KO  çane => zanea with dist=0.5000
# OK  econzazole => econazole with dist=0.1000
# KO  'en => hec with dist=0.6667
# OK  cylcleane => cycleane with dist=0.1111
# OK  séresta => seresta with dist=0.1429
# OK  abilfy => abilify with dist=0.1667
# OK  profenide => profenid with dist=0.1111
# OK  nozdaz => nordaz with dist=0.1667
# OK  ciprofloxacin => ciprofloxacine with dist=0.0769
# KO  lapres => alpress with dist=0.5000
# KO  uveline => aubeline with dist=0.2857
# KO  norvelo => norlevo with dist=0.2857
# OK  malox => maalox with dist=0.2000
# OK  mnaelle => menaelle with dist=0.1429
# OK  tanxene => tranxene with dist=0.1429
# OK  tardiferon => tardyferon with dist=0.1000
# OK  valériana => valeriana with dist=0.1111
# OK  sédaspir => sedaspir with dist=0.1250
# OK  rophylac => rhophylac with dist=0.1250
# KO  suveal => ludeal with dist=0.3333
# OK  depakot => depakote with dist=0.1429
# OK  millpertuis => millepertuis with dist=0.0909
# OK  météospasmyl => meteospasmyl with dist=0.1667
# OK  trinordio => trinordiol with dist=0.1111
# OK  pririx => priorix with dist=0.1667
# OK  meliodia => melodia with dist=0.1250
# KO  cyclen => cyclamen with dist=0.3333
# OK  ceresta => seresta with dist=0.1429
# KO  alrs => alko with dist=0.5000
# KO  sériane => srilane with dist=0.2857
# OK  magneb => magne with dist=0.1667
# OK  béconase => beconase with dist=0.1250
# KO  horeur => horus with dist=0.3333
# KO  arazc => arava with dist=0.4000
# OK  estréva => estreva with dist=0.1429
# OK  déstiner => dostinex with dist=0.2500
# KO  isoxan => isobar with dist=0.3333
# KO  sévere => savene with dist=0.3333

# %% [markdown]
# ## Active Ingredient name

# %%
ingredientNames = Counter(words(open('../../data/staging_data/ingredient_names.txt').read()))
exclusionList = set(list(misSpelledDrugMap.keys()) + list(drugNames))
misSpelledIngredientMap = buildFixMap(unknownWords, ingredientNames, 0.25, exclusionList, "../../data/staging_data/mispelled_ingredient_names.csv")
# Out:
# norset is already handled
# adepal is already handled
# solian is already handled
# tercian is already handled
# adépal is already handled
# clomid is already handled
# cycléane is already handled
# lumalia is already handled
# inexium is already handled
# lyoc is already handled
# cycleane is already handled
# skenan is already handled
# tolexine is already handled
# noroxine is already handled
# evepar is already handled
# depamide is already handled
# KO  dexorat => dextran with dist=0.2857
# gelsenium is already handled
# KO  apetit => apatite with dist=0.3333
# zoely is already handled
# granions is already handled
# dostinex is already handled
# fucidine is already handled
# depakine is already handled
# dépamide is already handled
# monazol is already handled
# lamisilate is already handled
# sertaline is already handled
# cacit is already handled
# pergotime is already handled
# modopar is already handled
# erythromycine is already handled
# KO  c'est => cyst with dist=0.4000
# ginkor is already handled
# coversyl is already handled
# imodium is already handled
# efexor is already handled
# lamisil is already handled
# pariet is already handled
# stimol is already handled
# econazole is already handled
# loxen is already handled
# KO  vacin => xarcin with dist=0.4000
# pivalone is already handled
# phosphorica is already handled
# fenofibrate is already handled
# veratran is already handled
# hydroxyquine is already handled
# azithromycin is already handled
# neupro is already handled
# alodont is already handled
# arpagophitum is already handled
# amoxicillin is already handled
# amoxiciline is already handled
# cefixime is already handled
# cetirizine is already handled
# KO  'il => til with dist=0.3333
# lantus is already handled
# KO  isoror => isotr with dist=0.3333
# KO  ventr => ent with dist=0.4000
# poralamine is already handled
# OK  dapis => apis with dist=0.2000
# desogestrel is already handled
# lodoz is already handled
# letrozole is already handled
# KO  someil => sommit with dist=0.3333
# KO  perimé => pyrim with dist=0.3333
# stinox is already handled
# KO  préso => press with dist=0.4000
# KO  buspar => bupr with dist=0.3333
# lobamine is already handled
# KO  les'il => besil with dist=0.3333
# terpone is already handled
# KO  enfet => ent with dist=0.4000
# spiriva is already handled
# KO  folic => solif with dist=0.4000
# fazol is already handled
# notran is already handled
# forlax is already handled
# OK  oestradiol => estradiol with dist=0.1000
# KO  qql => cl with dist=0.6667
# hydorcortisone is already handled
# differine is already handled
# trandate is already handled
# helicidine is already handled
# elevit is already handled
# vibramycine is already handled
# estrofem is already handled
# hydan is already handled
# minoxydil is already handled
# grifonia is already handled
# KO  athymil => thymol with dist=0.2857
# flucon is already handled
# varoline is already handled
# salbumol is already handled
# KO  apétit => apatite with dist=0.3333
# KO  pilul => pall with dist=0.4000
# adalate is already handled
# cyclean is already handled
# carbonica is already handled
# prograf is already handled
# surgam is already handled
# KO  azinc => amino with dist=0.4000
# gelsémium is already handled
# nexium is already handled
# bexero is already handled
# biomag is already handled
# KO  auco => aur with dist=0.5000
# tussidane is already handled
# xanac is already handled
# cafeine is already handled
# alprozolam is already handled
# OK  liloo => lilot with dist=0.2000
# orocal is already handled
# KO  exorex => norex with dist=0.3333
# KO  hctz => act with dist=0.5000
# ignitia is already handled
# amoxyciline is already handled
# imeth is already handled
# prosac is already handled
# amoxilline is already handled
# OK  clavunique => clavulanique with dist=0.2000
# ethinylestradiol is already handled
# chlormadione is already handled
# OK  acnee => actee with dist=0.2000
# KO  m'a => oka with dist=0.6667
# adenyl is already handled
# dtpe is already handled
# KO  urtile => uracile with dist=0.3333
# KO  qiue => nite with dist=0.5000
# amlor is already handled
# KO  ppelle => prele with dist=0.3333
# KO  anule => anol with dist=0.4000
# KO  sillice => silicea with dist=0.2857
# elavil is already handled
# ethinilestradiol is already handled
# KO  opsite => osine with dist=0.3333
# nebcine is already handled
# OK  hémifumarate => mifumarate with dist=0.1667
# KO  apnee => actee with dist=0.4000
# KO  èpas => apis with dist=0.5000
# KO  püis => pres with dist=0.5000
# OK  citr => acitr with dist=0.2500
# KO  soprol => toprof with dist=0.3333
# KO  qui'l => quinol with dist=0.4000
# KO  ethpo => ether with dist=0.4000
# gelsemiuim is already handled
# KO  flushs => fluph with dist=0.3333
# evista is already handled
# proitrine is already handled
# OK  raphnu's => raphanus with dist=0.2500
# KO  exès => exam with dist=0.5000
# KO  ingatia => ignatia with dist=0.2857
# mynocicline is already handled
# KO  alyna => avena with dist=0.4000
# OK  carabiné => larabine with dist=0.2500
# KO  ado' => gadot with dist=0.5000
# KO  pasdu => pasir with dist=0.4000
# KO  aspirne => asparte with dist=0.2857
# KO  efets => eftr with dist=0.4000
# azyter is already handled
# KO  consta => conestat with dist=0.3333
# KO  édans => ondans with dist=0.4000
# claritine is already handled
# betaine is already handled
# OK  teriflunomide => riflunomide with dist=0.1538
# KO  hcz => cl with dist=0.6667
# callendula is already handled
# protelos is already handled
# mydriaticum is already handled
# levofloxacine is already handled
# KO  concer => corce with dist=0.3333
# KO  gastros => gestrol with dist=0.2857
# KO  gonfe => mone with dist=0.4000
# OK  faot => fot with dist=0.2500
# magnevie is already handled
# hydrea is already handled
# KO  brulûre => bruyere with dist=0.2857
# KO  d'ou => dob with dist=0.5000
# KO  savir => salvia with dist=0.4000
# KO  'un => aun with dist=0.3333
# KO  plusa => plase with dist=0.4000
# panthoprazole is already handled
# OK  pendt => pent with dist=0.2000
# KO  rnale => riane with dist=0.4000
# josir is already handled
# OK  arpagophyton => harpagophyton with dist=0.0833
# KO  éatit => att with dist=0.4000
# KO  diance => riane with dist=0.3333
# OK  faringite => naringine with dist=0.2222
# KO  pendan => penta with dist=0.3333
# KO  jorai => toras with dist=0.4000
# granion is already handled
# cefpodoxine is already handled
# KO  jpren => pres with dist=0.4000
# létrozole is already handled
# zoély is already handled
# levothyroxine is already handled
# silecea is already handled
# secnol is already handled
# minazol is already handled
# actiq is already handled
# milepertuis is already handled
# KO  y'a => oka with dist=0.6667
# KO  norflex => norex with dist=0.2857
# gestodène is already handled
# KO  levre => vre with dist=0.4000
# KO  'ai => iii with dist=0.6667
# KO  arrèt => arr with dist=0.4000
# OK  abondans => ondans with dist=0.2500
# alteis is already handled
# norofloxacine is already handled

# %% [markdown]
# ## Common/Usual Term

# %%
exclusionList = set(list(exclusionList) + list(misSpelledIngredientMap.keys()) + list(ingredientNames))

# %%
from spellchecker import SpellChecker

spell = SpellChecker(language='fr')

misGeneralSpelledMap = {}
fileName = "../../data/staging_data/mispelled_general_words.csv"

for word in unknownWords:
    try:
        fixedWord = spell.correction(word)
    except:
        print("fail to fix word " + word)
        continue
        
    if fixedWord != word:            
        if word in exclusionList:
            continue
        dist = Levenshtein.distance(fixedWord, word) / len(word)            
        acceptFix = dist < 0.25
        flag = "OK" if acceptFix else "KO"
        # fix incorrect accent encoding...
        fixedWord = fixedWord.replace("ã¨", "è")
        fixedWord = fixedWord.replace("ã©", "é") 
        print("{3}  {0} => {1} with dist={2}".format(word, fixedWord, dist, flag))
        if acceptFix:           
            misGeneralSpelledMap[word] = fixedWord

writer = csv.writer(open(fileName, "w"), lineterminator='\r')
for key, val in misGeneralSpelledMap.items():
    writer.writerow([key, val])
# Out:
# OK  aujourd'hui => aujourdhui with dist=0.09090909090909091
# KO  j'ai => jai with dist=0.25
# KO  gygy => gay with dist=0.5
# OK  indesirables => indã©sirables with dist=0.16666666666666666
# OK  preservatif => prã©servatif with dist=0.18181818181818182
# KO  gelules => elles with dist=0.2857142857142857
# OK  préscrit => prescrit with dist=0.125
# KO  rubeole => rebelle with dist=0.2857142857142857
# KO  dexorat => deborah with dist=0.2857142857142857
# OK  qu’il => quil with dist=0.2
# KO  anxiete => anxieux with dist=0.2857142857142857
# OK  pilulle => pilule with dist=0.14285714285714285
# OK  apetit => petit with dist=0.16666666666666666
# KO  implanon => implants with dist=0.25
# OK  depresseur => dresseur with dist=0.2
# OK  gellules => cellules with dist=0.125
# OK  somnifere => somnifã¨re with dist=0.2222222222222222
# KO  nausees => fausses with dist=0.2857142857142857
# KO  deprime => prime with dist=0.2857142857142857
# KO  stodal => total with dist=0.3333333333333333
# OK  microdosée => microcosme with dist=0.2
# OK  homeopathie => homã©opathie with dist=0.18181818181818182
# OK  spottings => sporting with dist=0.2222222222222222
# OK  demangeaisons => dã©mangeaisons with dist=0.15384615384615385
# OK  c'est => cest with dist=0.2
# OK  grossese => grosses with dist=0.125
# OK  douleureuses => douloureuses with dist=0.08333333333333333
# OK  colliques => coliques with dist=0.1111111111111111
# OK  qu’on => quon with dist=0.2
# OK  seconadire => secondaire with dist=0.2
# OK  indesirable => indã©sirable with dist=0.18181818181818182
# OK  anxiolitique => anxiolytique with dist=0.08333333333333333
# OK  prescit => prescrit with dist=0.14285714285714285
# OK  vacin => vain with dist=0.2
# KO  trimgel => triage with dist=0.2857142857142857
# OK  anxiolitiques => anxiolytiques with dist=0.07692307692307693
# OK  neuroléptique => neuroleptiques with dist=0.15384615384615385
# OK  essouflée => essouffle with dist=0.2222222222222222
# KO  practon => preston with dist=0.2857142857142857
# OK  zonbie => zombie with dist=0.16666666666666666
# OK  spoting => sporting with dist=0.14285714285714285
# OK  gellule => cellule with dist=0.14285714285714285
# OK  repri => repris with dist=0.2
# OK  fatiguee => fatigue with dist=0.125
# KO  'il => il with dist=0.3333333333333333
# KO  dtpolio => polio with dist=0.2857142857142857
# KO  medocs => mecs with dist=0.3333333333333333
# OK  depresseurs => oppresseurs with dist=0.18181818181818182
# KO  isoror => isoler with dist=0.3333333333333333
# OK  gelule => gelula with dist=0.16666666666666666
# KO  monovax => donovan with dist=0.2857142857142857
# OK  ventr => venir with dist=0.2
# OK  simplemen => simplement with dist=0.1111111111111111
# OK  dadaptation => adaptation with dist=0.09090909090909091
# KO  acomplia => accomplir with dist=0.25
# KO  reméde => remise with dist=0.3333333333333333
# KO  anxieté => anxieux with dist=0.2857142857142857
# KO  desyrel => desiree with dist=0.2857142857142857
# OK  anxyolitique => anxiolytique with dist=0.16666666666666666
# OK  peremption => perception with dist=0.2
# OK  alergie => allergie with dist=0.14285714285714285
# OK  someil => soleil with dist=0.16666666666666666
# OK  comprimes => comprises with dist=0.1111111111111111
# KO  perimé => permis with dist=0.5
# KO  protègée => protege with dist=0.25
# OK  ovulé => ovule with dist=0.2
# OK  presrit => prescrit with dist=0.14285714285714285
# OK  anovulant => annulant with dist=0.2222222222222222
# OK  annorexie => anorexie with dist=0.1111111111111111
# OK  poussees => pousses with dist=0.125
# KO  préso => pris with dist=0.4
# KO  négaif => negatif with dist=0.3333333333333333
# KO  zacnan => kanan with dist=0.3333333333333333
# KO  buspar => buster with dist=0.3333333333333333
# OK  brulûres => brulures with dist=0.125
# OK  arretées => arretes with dist=0.125
# KO  les'il => leslie with dist=0.3333333333333333
# OK  plaits => plait with dist=0.16666666666666666
# OK  paupieres => papiers with dist=0.2222222222222222
# OK  prescrir => prescrit with dist=0.125
# KO  naussées => fausses with dist=0.25
# OK  enfet => effet with dist=0.2
# OK  poussee => pousser with dist=0.14285714285714285
# OK  folic => flic with dist=0.2
# KO  longtps => longtemps with dist=0.2857142857142857
# KO  genyco => geno with dist=0.3333333333333333
# OK  j'avais => javais with dist=0.14285714285714285
# KO  apercue => perdue with dist=0.2857142857142857
# KO  pouruqoi => pourquoi with dist=0.25
# OK  precrit => prescrit with dist=0.14285714285714285
# KO  qql => que with dist=0.6666666666666666
# OK  quelq'un => quelqun with dist=0.125
# OK  qu’est => quest with dist=0.16666666666666666
# OK  papilloma => papillon with dist=0.2222222222222222
# OK  remplacable => implacable with dist=0.18181818181818182
# OK  antitetanique => antitã©tanique with dist=0.15384615384615385
# OK  exiiste => existe with dist=0.14285714285714285
# KO  expidet => expire with dist=0.2857142857142857
# OK  bouffees => bouffes with dist=0.125
# OK  cèsse => casse with dist=0.2
# OK  gronchon => ronchon with dist=0.125
# OK  insommie => insomnie with dist=0.125
# KO  monasens => consens with dist=0.25
# KO  géllules => cellules with dist=0.25
# OK  comprim => compris with dist=0.14285714285714285
# KO  induies => inquiet with dist=0.2857142857142857
# KO  enervee => energie with dist=0.2857142857142857
# KO  apétit => petit with dist=0.3333333333333333
# OK  pilul => pilule with dist=0.2
# KO  arrètte => arrãªte with dist=0.2857142857142857
# KO  enervée => energie with dist=0.2857142857142857
# OK  imression => impression with dist=0.1111111111111111
# KO  defonce => fonce with dist=0.2857142857142857
# OK  qu’en => queen with dist=0.2
# OK  azinc => zinc with dist=0.2
# OK  antidepresseurs => antidã©presseurs with dist=0.13333333333333333
# OK  pilulles => pilules with dist=0.125
# KO  ermois => crois with dist=0.3333333333333333
# KO  qu’une => aucune with dist=0.3333333333333333
# OK  fiévre => fievre with dist=0.16666666666666666
# OK  weled => weed with dist=0.2
# KO  acneique => antique with dist=0.25
# KO  ostenil => obtenir with dist=0.2857142857142857
# OK  inquiter => inquieter with dist=0.125
# KO  auco => auto with dist=0.25
# KO  'année => annie with dist=0.3333333333333333
# OK  supositoire => suppositoire with dist=0.09090909090909091
# OK  dependante => cependant with dist=0.2
# KO  exorex => exode with dist=0.3333333333333333
# OK  obligatoiremen => obligatoirement with dist=0.07142857142857142
# KO  hctz => chez with dist=0.75
# OK  suportait => supportait with dist=0.1111111111111111
# OK  jattends => attends with dist=0.125
# OK  conseillerez => conseiller with dist=0.16666666666666666
# OK  est¨ce => estce with dist=0.16666666666666666
# KO  pylorii => pilori with dist=0.2857142857142857
# KO  emerger => berger with dist=0.2857142857142857
# KO  amoclane => mcclane with dist=0.25
# OK  hemoglobine => hã©moglobine with dist=0.18181818181818182
# OK  plakete => planete with dist=0.14285714285714285
# OK  interuption => interruption with dist=0.09090909090909091
# KO  m'a => ma with dist=0.3333333333333333
# OK  antiobiotique => antibiotique with dist=0.07692307692307693
# OK  chopée => chope with dist=0.16666666666666666
# KO  nénétte => nanette with dist=0.2857142857142857
# OK  raports => rapports with dist=0.14285714285714285
# OK  completemment => completement with dist=0.07692307692307693
# OK  psychlogue => psychologue with dist=0.1
# OK  jentendais => entendais with dist=0.1
# OK  urtile => utile with dist=0.16666666666666666
# KO  préscit => prescrit with dist=0.2857142857142857
# KO  qiue => que with dist=0.25
# KO  ambetant => ambulant with dist=0.25
# OK  quisse => puisse with dist=0.16666666666666666
# KO  adutles => adultes with dist=0.2857142857142857
# OK  ppelle => appelle with dist=0.16666666666666666
# KO  epaissit => ã©paissit with dist=0.25
# OK  medicamment => medicaments with dist=0.18181818181818182
# OK  anule => angle with dist=0.2
# OK  sillice => silice with dist=0.14285714285714285
# OK  coucheé => coucher with dist=0.14285714285714285
# KO  opsite => visite with dist=0.3333333333333333
# OK  ateinte => atteinte with dist=0.14285714285714285
# OK  augumenter => augmenter with dist=0.1
# OK  veroa => verra with dist=0.2
# OK  enceintre => enceinte with dist=0.1111111111111111
# OK  cocqueluche => coqueluche with dist=0.09090909090909091
# OK  cuive => cuire with dist=0.2
# OK  carrence => carence with dist=0.125
# OK  chiee => chien with dist=0.2
# KO  cutanee => cutanã©e with dist=0.2857142857142857
# KO  roseole => roscoe with dist=0.2857142857142857
# OK  apnee => annee with dist=0.2
# OK  anoncer => annoncer with dist=0.14285714285714285
# OK  aujourd'un => aujourdhui with dist=0.2
# OK  rappor => rapport with dist=0.16666666666666666
# OK  exeptionnels => exceptionnels with dist=0.08333333333333333
# OK  smaines => semaines with dist=0.14285714285714285
# OK  picotemments => picotements with dist=0.08333333333333333
# KO  calconel => colonel with dist=0.25
# KO  èpas => pas with dist=0.25
# OK  ultram => ultra with dist=0.16666666666666666
# OK  strees => street with dist=0.16666666666666666
# OK  angoisée => angoisse with dist=0.125
# OK  netrouve => retrouve with dist=0.125
# KO  püis => pris with dist=0.25
# OK  marront => marrant with dist=0.14285714285714285
# OK  contracetif => contraceptif with dist=0.09090909090909091
# OK  connaiser => connais with dist=0.2222222222222222
# OK  prennne => prenne with dist=0.14285714285714285
# OK  chlamidiae => chlamydia with dist=0.2
# OK  psychote => psychose with dist=0.125
# KO  eucal => lucas with dist=0.4
# KO  soprol => sorrow with dist=0.3333333333333333
# KO  cindelle => cannelle with dist=0.25
# OK  qui'l => quil with dist=0.2
# OK  siagnements => saignements with dist=0.18181818181818182
# OK  extremment => extremement with dist=0.1
# KO  ethpo => ethan with dist=0.4
# OK  disgestions => digestion with dist=0.18181818181818182
# OK  utiliiser => utiliser with dist=0.1111111111111111
# OK  boulimies => boulimie with dist=0.1111111111111111
# KO  douelurs => douleurs with dist=0.25
# OK  hallucinogéne => hallucinogã¨ne with dist=0.15384615384615385
# OK  cocceluche => coqueluche with dist=0.2
# OK  flushs => flashs with dist=0.16666666666666666
# OK  puisje => puisse with dist=0.16666666666666666
# OK  aujourdui => aujourdhui with dist=0.1111111111111111
# OK  douloureuze => douloureuse with dist=0.09090909090909091
# OK  osteoporose => ostã©oporose with dist=0.18181818181818182
# KO  govital => hopital with dist=0.2857142857142857
# OK  normalemnt => normalement with dist=0.1
# OK  scrupulesement => scrupuleusement with dist=0.07142857142857142
# OK  respectee => respecte with dist=0.1111111111111111
# KO  exès => es with dist=0.5
# OK  plaqettes => plaquettes with dist=0.1111111111111111
# OK  alyna => alina with dist=0.2
# OK  copinette => clopinettes with dist=0.2222222222222222
# OK  baillaient => brillaient with dist=0.1
# OK  gracial => gracias with dist=0.14285714285714285
# OK  limitte => limite with dist=0.14285714285714285
# KO  ado' => ado with dist=0.25
# OK  aujourdh'ui => aujourdhui with dist=0.09090909090909091
# OK  lananas => ananas with dist=0.14285714285714285
# OK  pamplemouss => pamplemousse with dist=0.09090909090909091
# KO  pasdu => pas with dist=0.4
# KO  gynelle => giselle with dist=0.2857142857142857
# OK  aspirne => aspirine with dist=0.14285714285714285
# KO  maschus => marcus with dist=0.2857142857142857
# KO  nausee => cause with dist=0.3333333333333333
# OK  efets => effets with dist=0.2
# KO  welada => nevada with dist=0.3333333333333333
# OK  pausse => passe with dist=0.16666666666666666
# OK  transission => transmission with dist=0.09090909090909091
# OK  homopathie => homã©opathie with dist=0.2
# OK  consta => costa with dist=0.16666666666666666
# KO  poukoi => pouvoir with dist=0.3333333333333333
# OK  édans => dans with dist=0.2
# OK  insemsible => insensible with dist=0.1
# OK  enchaines => chaines with dist=0.2222222222222222
# KO  sd'une => dune with dist=0.3333333333333333
# OK  prescrition => prescription with dist=0.09090909090909091
# KO  codion => coin with dist=0.3333333333333333
# OK  acoutumance => accoutumance with dist=0.09090909090909091
# OK  precris => prescris with dist=0.14285714285714285
# KO  hcz => cz with dist=0.3333333333333333
# OK  gynecologue => gynã©cologue with dist=0.18181818181818182
# KO  perléne => perle with dist=0.2857142857142857
# KO  trèès => trã¨s with dist=0.4
# OK  arrivepas => arriveras with dist=0.1111111111111111
# OK  cholesthérol => cholestã©rol with dist=0.16666666666666666
# KO  aminees => amies with dist=0.2857142857142857
# KO  dtvax => divan with dist=0.4
# OK  concer => cancer with dist=0.16666666666666666
# OK  marons => marins with dist=0.16666666666666666
# OK  gastros => gastro with dist=0.14285714285714285
# OK  gonfe => golfe with dist=0.2
# OK  lontemp => lontemps with dist=0.14285714285714285
# OK  plakettes => plaquettes with dist=0.2222222222222222
# OK  avisee => avise with dist=0.16666666666666666
# KO  anxios => adios with dist=0.3333333333333333
# KO  lannée => langue with dist=0.3333333333333333
# OK  perdrent => perdent with dist=0.125
# OK  completemen => completement with dist=0.09090909090909091
# KO  qi'il => vieil with dist=0.4
# OK  brulûre => brulure with dist=0.14285714285714285
# KO  d'ou => dou with dist=0.25
# KO  remergon => emerson with dist=0.25
# OK  pourwquoi => pourquoi with dist=0.1111111111111111
# OK  tolere => colere with dist=0.16666666666666666
# OK  exempls => exemple with dist=0.14285714285714285
# KO  explqier => expliquer with dist=0.25
# OK  iralande => irlande with dist=0.125
# KO  prennasi => prenais with dist=0.375
# OK  bronchiteux => bronchite with dist=0.18181818181818182
# OK  plaquete => plaquette with dist=0.125
# OK  est'elle => estelle with dist=0.125
# OK  disoluble => insoluble with dist=0.2222222222222222
# OK  intermittants => intermittente with dist=0.15384615384615385
# OK  piquûre => piqure with dist=0.14285714285714285
# KO  compeed => compte with dist=0.2857142857142857
# OK  porrai => pourrai with dist=0.16666666666666666
# OK  extrémment => extremement with dist=0.2
# OK  savir => savoir with dist=0.2
# KO  'un => un with dist=0.3333333333333333
# OK  plusa => plus with dist=0.2
# OK  rnale => anale with dist=0.2
# OK  juske => juste with dist=0.2
# KO  éatit => fait with dist=0.4
# OK  diance => diane with dist=0.16666666666666666
# OK  palquette => plaquette with dist=0.2222222222222222
# OK  arreterai => arretera with dist=0.1111111111111111
# OK  anxiolytiquess => anxiolytiques with dist=0.07142857142857142
# KO  deprimer => exprimer with dist=0.25
# OK  hazardeuses => hasardeuse with dist=0.18181818181818182
# OK  amplemant => amplement with dist=0.1111111111111111
# OK  pendan => pendant with dist=0.16666666666666666
# OK  jorai => jordi with dist=0.2
# OK  connàit => connait with dist=0.14285714285714285
# OK  dantalgique => antalgique with dist=0.09090909090909091
# KO  arrètent => arrivent with dist=0.25
# KO  jaimerer => aimerez with dist=0.25
# OK  pilositée => pilositã© with dist=0.2222222222222222
# OK  traitemnt => traitement with dist=0.1111111111111111
# KO  jpren => prend with dist=0.4
# OK  joubli => oubli with dist=0.16666666666666666
# KO  arvara => barbara with dist=0.3333333333333333
# OK  interompe => interrompe with dist=0.1111111111111111
# KO  reessaye => essaye with dist=0.25
# KO  deanxit => dealait with dist=0.2857142857142857
# KO  acouché => couche with dist=0.2857142857142857
# OK  entrainee => entrainer with dist=0.1111111111111111
# KO  griott => grotte with dist=0.3333333333333333
# OK  éssaie => essaie with dist=0.16666666666666666
# KO  pullile => publie with dist=0.2857142857142857
# OK  assimiliée => assimile with dist=0.2
# OK  japanaise => japonaise with dist=0.1111111111111111
# OK  dangereuxi => dangereux with dist=0.1
# KO  rituxan => ritchan with dist=0.2857142857142857
# KO  puced' => puce with dist=0.3333333333333333
# KO  espacant => essayant with dist=0.25
# OK  repondrai => rendrai with dist=0.2222222222222222
# OK  solager => soulager with dist=0.14285714285714285
# OK  decenbre => decembre with dist=0.125
# KO  protégee => proteger with dist=0.25
# OK  vaselinés => vaseline with dist=0.2222222222222222
# KO  poconéol => poconos with dist=0.25
# KO  jusq'au => jusqu with dist=0.2857142857142857
# KO  byzoux => bijoux with dist=0.3333333333333333
# KO  y'a => ya with dist=0.3333333333333333
# OK  duver => durer with dist=0.2
# KO  norflex => morfler with dist=0.2857142857142857
# OK  alternaive => alternative with dist=0.1
# OK  délivrais => livrais with dist=0.2222222222222222
# OK  grossessses => grossesses with dist=0.09090909090909091
# OK  levre => livre with dist=0.2
# OK  afronter => affronter with dist=0.125
# OK  sestompent => estompent with dist=0.1
# KO  'ai => ai with dist=0.3333333333333333
# OK  deprimais => exprimais with dist=0.2222222222222222
# OK  preventif => prã©ventif with dist=0.2222222222222222
# OK  narrines => narines with dist=0.125
# OK  vaccinnation => vaccination with dist=0.08333333333333333
# OK  arrèt => arret with dist=0.2
# OK  boufées => bouffes with dist=0.14285714285714285
# KO  égatif => latif with dist=0.3333333333333333
# KO  opèrer => opã©rer with dist=0.3333333333333333
# OK  represcrit => prescrit with dist=0.2
# OK  constiper => constater with dist=0.2222222222222222
# OK  jouire => jouir with dist=0.16666666666666666
# KO  alprax => alpha with dist=0.3333333333333333
# OK  antobiotiques => antibiotiques with dist=0.07692307692307693
# OK  comprimers => comprimer with dist=0.1
# OK  involonterement => involontairement with dist=0.13333333333333333
# KO  legeres => lettres with dist=0.2857142857142857
# OK  imréssion => impression with dist=0.2222222222222222
# KO  praluent => parlent with dist=0.375
# OK  freéquent => frã©quent with dist=0.2222222222222222
# KO  èa => la with dist=0.5
# OK  neurolepique => neurologique with dist=0.16666666666666666
# OK  cdnnait => connait with dist=0.14285714285714285
# OK  sutilise => utilise with dist=0.125
# KO  lutéal => futal with dist=0.3333333333333333
# OK  onfos => infos with dist=0.2
# OK  triatement => traitement with dist=0.2
# OK  standardises => standardiste with dist=0.16666666666666666
# OK  reveillant => rã©veillant with dist=0.2
# OK  remarker => remarier with dist=0.125
# KO  symtômes => symptomes with dist=0.25
# OK  palludisme => paludisme with dist=0.1
# OK  menstruer => menstruel with dist=0.1111111111111111
# KO  sterimar => steinar with dist=0.25
# OK  traiment => vraiment with dist=0.125
# OK  aujourd' => aujourd with dist=0.125
# KO  ovarine => marine with dist=0.2857142857142857
# KO  l'effet => effet with dist=0.2857142857142857
# KO  j'aurais => aurais with dist=0.25
# OK  diarrhees => diarrhã©es with dist=0.2222222222222222
# OK  arrèter => arreter with dist=0.14285714285714285
# KO  antelane => antenne with dist=0.25
# OK  debuté => debut with dist=0.16666666666666666
# KO  apaisyl => apaiser with dist=0.2857142857142857
# OK  associaton => association with dist=0.1
# OK  jvoudrais => voudrais with dist=0.1111111111111111
# KO  voulasi => voulais with dist=0.2857142857142857
# KO  tempsde => temps with dist=0.2857142857142857
# OK  milligrammmes => milligrammes with dist=0.07692307692307693
# OK  normalemen => normalement with dist=0.1
# OK  irritabilite => irritabilitã© with dist=0.16666666666666666
# OK  nervosite => nervositã© with dist=0.2222222222222222
# OK  réjouissais => rã©jouissais with dist=0.18181818181818182
# OK  taritement => traitement with dist=0.2
# KO  nauseuse => danseuse with dist=0.25
# OK  beaucoupp => beaucoup with dist=0.1111111111111111
# OK  beance => beanie with dist=0.16666666666666666
# OK  majoriter => majoritã© with dist=0.2222222222222222
# KO  ocntre => contre with dist=0.3333333333333333
# OK  intestinuax => intestinaux with dist=0.18181818181818182
# OK  revaccination => vaccination with dist=0.15384615384615385
# KO  sojayam => soraya with dist=0.2857142857142857
# OK  jsais => sais with dist=0.2
# OK  repenne => reprenne with dist=0.14285714285714285
# OK  servrage => sevrage with dist=0.125
# OK  apparuent => apparent with dist=0.1111111111111111
# OK  altérnance => alternance with dist=0.1
# KO  synecod => synced with dist=0.2857142857142857
# OK  logntemps => longtemps with dist=0.2222222222222222
# KO  thékan => than with dist=0.3333333333333333
# KO  nausé => nous with dist=0.4
# OK  athme => asthme with dist=0.2
# KO  'eau => eau with dist=0.25
# OK  grossess => grosses with dist=0.125
# OK  attroces => atroces with dist=0.125
# KO  clozan => clan with dist=0.3333333333333333
# OK  pilue => pile with dist=0.2
# OK  tombee => tomber with dist=0.16666666666666666
# KO  àn'a => anna with dist=0.5
# OK  sparmes => spasmes with dist=0.14285714285714285
# KO  urilisée => utilise with dist=0.25
# KO  plillul => pillule with dist=0.2857142857142857
# OK  loccurence => occurrence with dist=0.2
# OK  peuven => peuvent with dist=0.16666666666666666
# OK  arrét => arret with dist=0.2
# KO  abcés => abus with dist=0.4
# OK  rehydrater => hydrater with dist=0.2
# KO  oomg => omg with dist=0.25
# OK  supossitoire => suppositoire with dist=0.16666666666666666
# OK  anevrisme => anã©vrisme with dist=0.2222222222222222
# OK  posotif => positif with dist=0.14285714285714285
# OK  oppréssée => oppresse with dist=0.2222222222222222
# OK  profondémment => profondã©ment with dist=0.15384615384615385
# OK  dhier => hier with dist=0.2
# OK  daujourdhui => aujourdhui with dist=0.09090909090909091
# OK  voualais => voulais with dist=0.125
# OK  inquieté => inquiet with dist=0.125
# KO  execive => exercice with dist=0.2857142857142857
# KO  synvisc => syndic with dist=0.2857142857142857
# OK  ashme => asthme with dist=0.2
# KO  baldrian => adrian with dist=0.25
# KO  kelkun => kelvin with dist=0.3333333333333333
# KO  prepause => repasse with dist=0.25
# OK  rsultat => resultat with dist=0.14285714285714285
# KO  dégouts => ã©gouts with dist=0.2857142857142857
# OK  seconadaires => secondaires with dist=0.08333333333333333
# KO  gagnerdu => gagner with dist=0.25
# OK  èjour => jour with dist=0.2
# OK  tempq => temps with dist=0.2
# OK  'fragile' => fragile with dist=0.2222222222222222
# OK  jaurai => aurai with dist=0.16666666666666666
# OK  aujordhui => aujourdhui with dist=0.1111111111111111
# OK  adminsitrer => administrer with dist=0.18181818181818182
# OK  encorre => encore with dist=0.14285714285714285
# OK  acunpuncteur => acupuncteur with dist=0.08333333333333333
# KO  camarche => marche with dist=0.25
# OK  eprouve => prouve with dist=0.14285714285714285
# OK  adulter => adulte with dist=0.14285714285714285
# OK  commener => commencer with dist=0.125
# KO  rhumato => traumato with dist=0.2857142857142857
# OK  pediatrique => pã©diatrique with dist=0.18181818181818182
# OK  c’est => cest with dist=0.2
# OK  rembooursé => rembourse with dist=0.2
# KO  entriane => entraine with dist=0.25
# OK  redors => retors with dist=0.16666666666666666
# OK  qu’elle => quelle with dist=0.14285714285714285
# KO  benivit => benoit with dist=0.2857142857142857
# OK  resenti => ressenti with dist=0.14285714285714285
# OK  ressembaient => ressemblaient with dist=0.08333333333333333
# KO  gonglé => google with dist=0.3333333333333333
# KO  préscite => prescrite with dist=0.25
# KO  defensia => defense with dist=0.25
# KO  normix => dormir with dist=0.3333333333333333
# OK  detruites => dã©truites with dist=0.2222222222222222
# OK  repondront => rendront with dist=0.2
# OK  constipée => constitue with dist=0.2222222222222222
# OK  rembourssement => remboursement with dist=0.07142857142857142
# OK  aujourd'jui => aujourdhui with dist=0.18181818181818182
# OK  rescente => descente with dist=0.125
# OK  symptmes => symptomes with dist=0.125
# KO  prottegé => protege with dist=0.25
# OK  déprimais => exprimais with dist=0.2222222222222222
# OK  remarché => remarche with dist=0.125
# KO  pchit => petit with dist=0.4
# OK  noctifs => nocifs with dist=0.14285714285714285
# OK  ftigue => fatigue with dist=0.16666666666666666
# OK  exacement => exactement with dist=0.1111111111111111
# KO  depassai => repassait with dist=0.25
# OK  tremblotte => tremblote with dist=0.1
# OK  lalybelle => maybelle with dist=0.2222222222222222
# KO  arrêtér => arreter with dist=0.2857142857142857
# OK  examans => examens with dist=0.14285714285714285
# OK  encinte => enceinte with dist=0.14285714285714285
# KO  immovan => immoral with dist=0.2857142857142857
# OK  pictotements => picotements with dist=0.08333333333333333
# OK  entrainne => entraine with dist=0.1111111111111111
# OK  commercialisez => commercialiser with dist=0.07142857142857142
# OK  pillulle => pillule with dist=0.125
# OK  nausez => causez with dist=0.16666666666666666
# OK  jutilise => utilise with dist=0.125
# OK  cconnaissez => connaissez with dist=0.09090909090909091
# KO  nuitce => nuit with dist=0.3333333333333333
# OK  aupparavant => auparavant with dist=0.09090909090909091
# OK  medcin => medecin with dist=0.16666666666666666
# OK  dangeer => danger with dist=0.14285714285714285
# OK  petzouille => patrouille with dist=0.2
# OK  surdosade => surdose with dist=0.2222222222222222
# KO  lpmg => long with dist=0.5
# KO  quleque => quelque with dist=0.2857142857142857
# KO  oedeme => oedã¨me with dist=0.3333333333333333
# KO  quesquil => quesque with dist=0.25
# OK  differament => different with dist=0.18181818181818182
# OK  suporte => supporte with dist=0.14285714285714285
# OK  déconditionne => conditionne with dist=0.15384615384615385
# OK  conaissez => connaissez with dist=0.1111111111111111
# OK  synusite => sinusite with dist=0.125
# OK  manquai => manquait with dist=0.14285714285714285
# OK  jarsin => jardin with dist=0.16666666666666666
# OK  cuilleres => cuillers with dist=0.1111111111111111
# KO  decramp => duchamp with dist=0.2857142857142857
# KO  d'eau => dieu with dist=0.4
# OK  convultions => convulsions with dist=0.09090909090909091
# OK  ateints => atteints with dist=0.14285714285714285
# KO  puovait => pouvait with dist=0.2857142857142857
# OK  attendrent => attendent with dist=0.1
# KO  evanouir => ã©vanouir with dist=0.25
# OK  grossessse => grossesse with dist=0.1
# KO  genertº => general with dist=0.2857142857142857
# KO  aprèsc => apres with dist=0.3333333333333333
# OK  revomit => revoit with dist=0.14285714285714285
# KO  paupiere => papier with dist=0.25
# OK  'involontairement' => involontairement with dist=0.1111111111111111
# OK  pdant => puant with dist=0.2
# KO  célexa => alexa with dist=0.3333333333333333
# OK  essuyais => essayais with dist=0.125
# OK  ordonannce => ordonnance with dist=0.2
# OK  létranger => ã©tranger with dist=0.2222222222222222
# OK  medicamnt => medicaments with dist=0.2222222222222222
# OK  simulaires => similaires with dist=0.1
# OK  tabbagisme => tabagisme with dist=0.1
# KO  diarrée => diacre with dist=0.2857142857142857
# KO  alpraz => alpha with dist=0.3333333333333333
# OK  declenche => dã©clenche with dist=0.2222222222222222
# OK  transmettions => transmettons with dist=0.07692307692307693
# OK  landemain => lendemain with dist=0.1111111111111111
# KO  môi => moi with dist=0.3333333333333333
# OK  mèrci => merci with dist=0.2
# OK  disparraitre => disparaitre with dist=0.08333333333333333
# KO  ginéco => gino with dist=0.3333333333333333
# OK  epouvantables => epouvantable with dist=0.07692307692307693
# KO  receptif => rã©ceptif with dist=0.25
# KO  ejaculer => enculer with dist=0.25
# OK  nomal => normal with dist=0.2
# OK  differrence => difference with dist=0.09090909090909091
# OK  saignemen => saignement with dist=0.1111111111111111
# OK  prisle => prise with dist=0.16666666666666666
# OK  quesqui => quesque with dist=0.14285714285714285
# KO  bicar => car with dist=0.4
# OK  augmentassion => augmentation with dist=0.15384615384615385
# OK  renouvellable => renouvelable with dist=0.07692307692307693
# OK  saingements => saignements with dist=0.18181818181818182
# OK  habituee => habitude with dist=0.125
# OK  gossesse => grossesse with dist=0.125
# OK  bustar => buster with dist=0.16666666666666666
# KO  myelite => elite with dist=0.2857142857142857
# OK  antidepresseur => antidã©presseur with dist=0.14285714285714285
# OK  obssesions => obsessions with dist=0.2
# OK  tristesse… => tristesse with dist=0.1
# OK  avalais => valais with dist=0.14285714285714285
# OK  syptomes => symptomes with dist=0.125
# OK  depressif => dã©pressif with dist=0.2222222222222222
# OK  reseignement => renseignement with dist=0.08333333333333333
# KO  etreune => etienne with dist=0.2857142857142857
# OK  contracetive => contraceptives with dist=0.16666666666666666
# KO  pressicé => pression with dist=0.25
# KO  synsvic => syndic with dist=0.2857142857142857
# KO  qu’à => que with dist=0.5
# KO  diahree => diacre with dist=0.2857142857142857
# OK  traitemen => traitement with dist=0.1111111111111111
# OK  hematocrite => hã©matocrite with dist=0.18181818181818182
# OK  préscrire => prescrire with dist=0.1111111111111111
# OK  metastases => mã©tastases with dist=0.2
# OK  interragir => interagir with dist=0.1
# OK  prendait => prenait with dist=0.125
# KO  seulmen => seule with dist=0.2857142857142857
# OK  lotre => votre with dist=0.2
# KO  plutar => plupart with dist=0.3333333333333333
# KO  seméne => semaine with dist=0.3333333333333333
# KO  prochéne => prochaine with dist=0.25
# KO  édé => de with dist=0.6666666666666666
# OK  quelq’un => quelqun with dist=0.125
# KO  ……mon => mon with dist=0.4
# OK  prescript => prescrit with dist=0.1111111111111111
# OK  medicament… => medicaments with dist=0.09090909090909091
# OK  quelqu’un => quelquun with dist=0.1111111111111111
# OK  desintoxiquer => dã©sintoxiquer with dist=0.15384615384615385
# OK  pouvaot => pouvait with dist=0.14285714285714285
# OK  debarasser => dã©barasser with dist=0.2
# KO  comrpimé => comprime with dist=0.375
# OK  protegeait => protã©geait with dist=0.2
# OK  commancer => commencer with dist=0.1111111111111111
# OK  tagagisme => tabagisme with dist=0.1111111111111111
# OK  j'imagine => imagine with dist=0.2222222222222222
# KO  reaparue => reparle with dist=0.25
# OK  occassionnellement => occasionnellement with dist=0.05555555555555555
# OK  gestue => geste with dist=0.16666666666666666
# OK  nterrations => aberrations with dist=0.18181818181818182
# OK  acvant => avant with dist=0.16666666666666666
# KO  kkun => kun with dist=0.25
# OK  incompatibilitée => incompatibilitã© with dist=0.125
# KO  dailygé => daily with dist=0.2857142857142857
# OK  d'anorexique => anorexique with dist=0.16666666666666666
# KO  aïh => ah with dist=0.3333333333333333
# OK  précotions => promotions with dist=0.2
# OK  ancipation => animation with dist=0.2
# KO  angoises => angoisse with dist=0.25
# OK  prescri => prescrit with dist=0.14285714285714285
# OK  efferts => effets with dist=0.14285714285714285
# OK  prescire => prescrire with dist=0.125
# OK  râter => rater with dist=0.2
# KO  peut'on => peyton with dist=0.2857142857142857
# OK  commençer => commencer with dist=0.1111111111111111
# KO  triofan => tristan with dist=0.2857142857142857
# KO  lerivon => levon with dist=0.2857142857142857
# KO  antidep => antigel with dist=0.2857142857142857
# KO  aguiller => fouiller with dist=0.25
# OK  pharmatienne => pharmacienne with dist=0.08333333333333333
# OK  irregulier => irrã©gulier with dist=0.2
# OK  gastrologue => astrologue with dist=0.09090909090909091
# KO  generik => general with dist=0.2857142857142857
# KO  bcgite => bite with dist=0.3333333333333333
# KO  codeïne => moderne with dist=0.2857142857142857
# OK  represcrite => prescrite with dist=0.18181818181818182
# OK  dangerueux => dangereux with dist=0.1
# OK  recommencais => recommences with dist=0.16666666666666666
# OK  derinieres => dernieres with dist=0.1
# OK  telephoner => telephone with dist=0.1
# OK  autoriss => autorise with dist=0.125
# KO  celexa => cela with dist=0.3333333333333333
# OK  precieusement => gracieusement with dist=0.15384615384615385
# OK  rrien => rien with dist=0.2
# OK  jmenferme => enferme with dist=0.2222222222222222
# KO  bizouu => bijoux with dist=0.3333333333333333
# KO  jaimeré => aimer with dist=0.2857142857142857
# KO  j'étais => jetais with dist=0.2857142857142857
# OK  gttes => gates with dist=0.2
# KO  maitake => maitre with dist=0.2857142857142857
# KO  voligab => volga with dist=0.2857142857142857
# KO  çane => jane with dist=0.25
# OK  fillait => fallait with dist=0.14285714285714285
# OK  arréte => arrete with dist=0.16666666666666666
# OK  médicments => medicaments with dist=0.2
# OK  latuda => lauda with dist=0.16666666666666666
# OK  consitions => conditions with dist=0.1
# KO  'en => en with dist=0.3333333333333333
# OK  prendres => prendre with dist=0.125
# OK  supositoires => suppositoires with dist=0.08333333333333333
# OK  continur => continue with dist=0.125
# OK  posotion => position with dist=0.125
# OK  métho => mytho with dist=0.2
# OK  reglée => regle with dist=0.16666666666666666
# KO  repulsif => impulsif with dist=0.25
# OK  lapres => apres with dist=0.16666666666666666
# OK  levvr => lever with dist=0.2
# OK  augementation => augmentation with dist=0.07692307692307693
# KO  uveline => veine with dist=0.2857142857142857
# KO  norvelo => nouvel with dist=0.2857142857142857
# KO  comandé => commande with dist=0.2857142857142857
# OK  linterieur => interieur with dist=0.1
# OK  epoursuivre => poursuivre with dist=0.09090909090909091
# OK  rehercher => rechercher with dist=0.1111111111111111
# OK  emdormir => endormir with dist=0.125
# KO  pbms => pbs with dist=0.25
# OK  deconseiller => conseiller with dist=0.16666666666666666
# OK  allerqique => allergique with dist=0.1
# KO  risuqe => risque with dist=0.3333333333333333
# OK  anitbiotique => antibiotique with dist=0.16666666666666666
# OK  samedie => samedi with dist=0.14285714285714285
# OK  quasimant => quasiment with dist=0.1111111111111111
# OK  simplemant => simplement with dist=0.1
# OK  suproduction => production with dist=0.16666666666666666
# OK  preparées => prepare with dist=0.2222222222222222
# OK  ecoeur => coeur with dist=0.16666666666666666
# OK  bibéron => biberon with dist=0.14285714285714285
# KO  suveal => seal with dist=0.3333333333333333
# OK  anesthesier => anesthã©sier with dist=0.18181818181818182
# OK  longtements => longuement with dist=0.18181818181818182
# OK  reagissait => agissait with dist=0.2
# OK  blulure => brulure with dist=0.14285714285714285
# OK  cyclen => cycle with dist=0.16666666666666666
# OK  oesophagite => oesophage with dist=0.18181818181818182
# OK  secodnaires => secondaires with dist=0.18181818181818182
# OK  cremeuses => creuses with dist=0.2222222222222222
# KO  sériane => ariane with dist=0.2857142857142857
# KO  réesayer => relayer with dist=0.25
# OK  horeur => horreur with dist=0.16666666666666666
# OK  renouvler => renouveler with dist=0.1111111111111111
# OK  vraimnt => vraiment with dist=0.14285714285714285
# KO  arazc => franc with dist=0.4
# OK  'differente' => differente with dist=0.16666666666666666
# KO  cutannée => cutanã©e with dist=0.25
# KO  isoxan => isolant with dist=0.3333333333333333
# KO  sévere => revere with dist=0.3333333333333333
# KO  aclool => alcool with dist=0.3333333333333333
# KO  répulser => expulser with dist=0.25
# OK  clamydiae => chlamydia with dist=0.2222222222222222
# KO  baralgin => baratin with dist=0.25

# %%
from tqdm import tqdm
import os, re, csv, math, codecs
import numpy as np

embeddings_index = {}
f = codecs.open('../../pretrained_models/fasttext/wiki.fr.vec', encoding='utf-8')
for line in tqdm(f):
    values = line.rstrip().rsplit(' ')
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
# Out:
# 1152466it [02:25, 7911.68it/s]

# %%
import pandas as pd
# save the fasttext vocabulary
fasttext_vocab = list(embeddings_index.keys())
pd.DataFrame(fasttext_vocab).to_csv('../../data/staging_data/fasttext_vocabulary.txt', header=None, index=None)

# %%
fasttext_vocab = set(fasttext_vocab)
fixedWordSize = len(misGeneralSpelledMap.values())
knownFixedWordSize = 0
stillUnknownFixedWords = set()
for w in misGeneralSpelledMap.values():
    if w in fasttext_vocab:
        knownFixedWordSize = knownFixedWordSize + 1
    else:
        stillUnknownFixedWords.add(w)
remainingUnknownWordSize = len(setUnknownWords) - len(misGeneralSpelledMap) - len(misSpelledDrugMap) - len(misSpelledIngredientMap)
print("Ratio of fixed words which are still recognized by fasttext model = {0}".format(float(knownFixedWordSize) / float(fixedWordSize)))
# Out:
# Ratio of fixed words which are still recognized by fasttext model = 0.9957264957264957

# %% [markdown]
# ## Unknown word residue

# %%
unknownWordResidue = set(unknownWords)
remainingUnknownWordSize = len(setUnknownWords) - len(misGeneralSpelledMap) - len(misSpelledDrugMap) - len(misSpelledIngredientMap)
print("remaining unknown word size = {0}".format(remainingUnknownWordSize))
# Out:
# remaining unknown word size = 300

# %%
unknownWordResidue.difference_update(misGeneralSpelledMap.keys())
unknownWordResidue.difference_update(misSpelledDrugMap.keys())
unknownWordResidue.difference_update(misSpelledIngredientMap.keys())
unknownWordResidue.difference_update(ingredientNames)
unknownWordResidue.difference_update(drugNames)
unknownWordResidue
pd.DataFrame(list(unknownWordResidue)).to_csv('../../data/staging_data/fasttext_outofvocab_words_residue.txt', header=None, index=None)
