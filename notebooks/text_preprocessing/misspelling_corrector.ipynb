# %%
# in-cell python script comes from https://norvig.com/spell-correct.html resource
import re
from collections import Counter

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('C:/Users/I051796/Projects/ANSM/drugs.txt').read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
with open('C:/Users/I051796/Projects/CES/temp/unknown.txt',encoding='utf-8') as f:
    unknownWords = f.read().splitlines()

# %%
from spellchecker import SpellChecker
spellChecker = SpellChecker(language='fr')

misSpelledMap = {}

for word in unknownWords:
    # try first to identify a medicine name
    fixedWord = correction(word)
    if fixedWord != word:
        print("{0} => {1}".format(word, fixedWord))
        misSpelledMap[word] = fixedWord

writer = csv.writer(open("C:/Users/I051796/Projects/CES/temp/misspellmap.csv", "w"))
for key, val in misSpelledMap.items():
    writer.writerow([key, val])
# Out:
# qest => post
# sterilet => sterilene
# gygy => gyno
# lumalia => fumaria
# lyoc => lyo
# seroquel => xeroquel
# dexorat => deroxat
# anxiete => anxietum
# gelsenium => gelsemium
# apetit => apatite
# calcibronate => calcibronat
# seropam => seropram
# deprime => delprim
# androcure => androcur
# efflexor => effexor
# sertaline => sertraline
# corticoide => coricide
# infarix => infanrix
# lisanxia => lysanxia
# orgastoro => ogastoro
# remicad => remicade
# efexor => effexor
# temestat => temesta
# lysopaine => lysocline
# lexomyl => lexomil
# qon => nol
# vacin => cacit
# trinordiole => trinordiol
# luthényl => lutenyl
# phosphorica => phosphoricum
# minidrill => minidril
# efféralgant => efferalgan
# hydroxyquine => hydroxyzine
# azithromycin => azithromycine
# arkogellules => arkogelules
# arpagophitum => harpagophytum
# amoxicillin => amoxicilline
# amoxiciline => amoxicilline
# repri => reparil
# 'il => nol
# lysenxia => lysanxia
# séropam => seropram
# locoïd => locoid
# ...
