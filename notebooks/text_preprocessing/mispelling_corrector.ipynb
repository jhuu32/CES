# %% [markdown]
# ## Mispelling Corrector
# Fix the training text by substituing identified mispelled words by its fix suggestion: the word->fixed_vord maps are generated by this [notebook](mispelling_map_builder.ipynb) and materialized in staging_data csv files.
# This notebook produces the [mispelling_fixed_clean_input_train.csv](../../data/staging_data/mispelling_fixed_clean_input_train.csv) file

# %%
# load first all mispelling fix map
import csv

def loadFixMap(fileName):
    reader = csv.reader(open(fileName, 'r'))
    fixMap = {}
    for row in reader:
       k, v = row
       fixMap[k] = v
    return fixMap

drugFixMap = loadFixMap('../../data/staging_data/mispelled_drug_names.csv')
ingredientFixMap = loadFixMap('../../data/staging_data/mispelled_ingredient_names.csv')
generalFixMap = loadFixMap('../../data/staging_data/mispelled_general_names.csv')
drugFixMap
# Out:
# {'cérazette': 'cerazette',
#  'adépal': 'adepal',
#  'sterilet': 'sterilene',
#  'lutéran': 'luteran',
#  'cycléane': 'cycleane',
#  'lyoc': 'lyo',
#  'seroquel': 'xeroquel',
#  'triafémi': 'triafemi',
#  'lutényl': 'lutenyl',
#  'désobel': 'desobel',
#  'déroxat': 'deroxat',
#  'gelsenium': 'gelsemium',
#  'séropram': 'seropram',
#  'prévenar': 'prevenar',
#  'lévothyrox': 'levothyrox',
#  'calcibronate': 'calcibronat',
#  'seropam': 'seropram',
#  'miréna': 'mirena',
#  'bétaserc': 'betaserc',
#  'dépamide': 'depamide',
#  'androcure': 'androcur',
#  'holgyème': 'holgyeme',
#  'efflexor': 'effexor',
#  'sertaline': 'sertraline',
#  'remicad': 'remicade',
#  'strésam': 'stresam',
#  'corticoide': 'coricide',
#  'infarix': 'infanrix',
#  'lisanxia': 'lysanxia',
#  'xénical': 'xenical',
#  'orgastoro': 'ogastoro',
#  'vogalène': 'vogalene',
#  'téralithe': 'teralithe',
#  'efexor': 'effexor',
#  'temestat': 'temesta',
#  'lysopaine': 'lysocline',
#  'lexomyl': 'lexomil',
#  'stédiril': 'stediril',
#  'spéciafoldine': 'speciafoldine',
#  'monéva': 'moneva',
#  'équanil': 'equanil',
#  'trinordiole': 'trinordiol',
#  'luthényl': 'lutenyl',
#  'tégrétol': 'tegretol',
#  'phosphorica': 'phosphoricum',
#  'méningitec': 'meningitec',
#  'minidrill': 'minidril',
#  'débridat': 'debridat',
#  'efféralgant': 'efferalgan',
#  'hydroxyquine': 'hydroxyzine',
#  'azithromycin': 'azithromycine',
#  'arkogellules': 'arkogelules',
#  'sporténine': 'sportenine',
#  'théralène': 'theralene',
#  'evépar': 'evepar',
#  'dépakote': 'depakote',
#  'léxomil': 'lexomil',
#  'arpagophitum': 'harpagophytum',
#  'amoxicillin': 'amoxicilline',
#  'rocéphine': 'rocephine',
#  'amoxiciline': 'amoxicilline',
#  'décontractyl': 'decontractyl',
#  'lysenxia': 'lysanxia',
#  'norlévo': 'norlevo',
#  'locoïd': 'locoid',
#  'miness': 'minesse',
#  'meningite': 'meningitec',
#  'biceptine': 'biseptine',
#  'fortimel': 'fortigel',
#  'roacutane': 'roaccutane',
#  'stillnox': 'stilnox',
#  'luthenyl': 'lutenyl',
#  'segement': 'serevent',
#  'trimordiol': 'trinordiol',
#  'poralamine': 'polaramine',
#  'yasminelle': 'jasminelle',
#  'alvocardyl': 'avlocardyl',
#  'stinox': 'stilnox',
#  'efféralgan': 'efferalgan',
#  'nuraving': 'nuvaring',
#  'cerrazette': 'cerazette',
#  'priopix': 'priorix',
#  'tardyféron': 'tardyferon',
#  'néoral': 'neoral',
#  'solumédrol': 'solumedrol',
#  'notran': 'noctran',
#  'kardégic': 'kardegic',
#  'pentacoq': 'pentacis',
#  'gardasyl': 'gardasil',
#  'hydorcortisone': 'hydrocortisone',
#  'sterilets': 'sterilene',
#  'minoxydil': 'minoxidil',
#  'grifonia': 'agrimonia',
#  'zythromax': 'zithromax',
#  'varoline': 'varnoline',
#  'viscéralgine': 'visceralgine',
#  'abilyfy': 'abilify',
#  'clarytine': 'clarityne',
#  'dolipranes': 'doliprane',
#  'immurel': 'imurel',
#  'stomectol': 'stromectol',
#  'hypericine': 'hyperamine',
#  'risperal': 'risperdal',
#  'relaxis': 'revaxis',
#  'ménopur': 'menopur',
#  'cyclean': 'cycleane',
#  'carbonica': 'carbonicum',
#  'abilifly': 'abilify',
#  'curacnée': 'curacne',
#  'minidrile': 'minidril',
#  'périactine': 'periactine',
#  'tetrazepan': 'tetrazepam',
#  'progesteronum': 'progesterone',
#  'séroquel': 'xeroquel',
#  'gelsémium': 'gelsemium',
#  'strepsil': 'strepsils',
#  'prevnar': 'prevenar',
#  'tetramysal': 'tetralysal',
#  'bexero': 'bexsero',
#  'microvial': 'microval',
#  'xanac': 'xanax',
#  'antibios': 'antibio',
#  'bromazepan': 'bromazepam',
#  'alprozolam': 'alprazolam',
#  'euphitose': 'euphytose',
#  'jasminielle': 'jasminelle',
#  'aturgil': 'aturgyl',
#  'ignitia': 'ignatia',
#  'hélicobacter': 'helicobacter',
#  'amoxyciline': 'amoxicilline',
#  'steriler': 'sterilene',
#  'prosac': 'prozac',
#  'celestène': 'celestene',
#  'amoxilline': 'amoxicilline',
#  'trinordyol': 'trinordiol',
#  'chlormadione': 'chlormadinone',
#  'spotog': 'spotof',
#  'curacné': 'curacne',
#  'kétoderm': 'ketoderm',
#  'dtpe': 'dtpa',
#  'estrev': 'estreva',
#  'ténoretic': 'tenoretic',
#  'stérogyl': 'sterogyl',
#  'tricelest': 'tricilest',
#  'naxproxen': 'naproxene',
#  'ethinilestradiol': 'ethinylestradiol',
#  'célestene': 'celestene',
#  'orgametil': 'orgametril',
#  'kardefic': 'kardegic',
#  'extranaze': 'extranase',
#  'avocardil': 'avlocardyl',
#  'gardazil': 'gardasil',
#  'triafermi': 'triafemi',
#  'duphastone': 'duphaston',
#  'detoxat': 'deroxat',
#  'optidtil': 'optidril',
#  'optimisette': 'optimizette',
#  'gardasi': 'gardasil',
#  'gelsemiuim': 'gelsemium',
#  'déturgylone': 'deturgylone',
#  'gerdazil': 'gardasil',
#  'floxifral': 'floxyfral',
#  'proitrine': 'prostine',
#  'voltaréne': 'voltarene',
#  'andorcur': 'androcur',
#  'mynocicline': 'minocycline',
#  'naturland': 'natulan',
#  'dolyprane': 'doliprane',
#  'cytotek': 'cytotec',
#  'ludeale': 'ludeal',
#  'oeuphytoses': 'euphytose',
#  'seoplex': 'seroplex',
#  'floradil': 'foradil',
#  'alverine': 'elvorine',
#  'kethoderm': 'ketoderm',
#  'urosuphon': 'urosiphon',
#  'physiogyne': 'physiogine',
#  'trophicrème': 'trophicreme',
#  'paracétamole': 'paracetamol',
#  'ymbicort': 'symbicort',
#  'provannes': 'provames',
#  'claritine': 'clarityne',
#  'modlodal': 'modiodal',
#  'orbénine': 'orbenine',
#  'colposeptine…': 'colposeptine',
#  'attarax': 'atarax',
#  'lorezepam': 'lorazepam',
#  'callendula': 'calendula',
#  'magnogène': 'magnogene',
#  'jasminellee': 'jasminelle',
#  'tronordiol': 'trinordiol',
#  'pontalgine': 'prontalgine',
#  'immovane': 'imovane',
#  'josacyne': 'josacine',
#  'caseine': 'cafeine',
#  'eucaliptine': 'eucalyptine',
#  'leffexor': 'effexor',
#  'anserine': 'mianserine',
#  'jesminelle': 'jasminelle',
#  'mifégyne': 'mifegyne',
#  'europhytose': 'euphytose',
#  'effexo': 'effexor',
#  'bélara': 'belara',
#  'mométasone': 'mometasone',
#  'lozazepam': 'lorazepam',
#  'carbopol': 'carbophos',
#  'spiromax': 'epitomax',
#  'lixanxia': 'lysanxia',
#  'transpeg': 'transipeg',
#  'ibiprofene': 'ibuprofene',
#  'ponstil': 'ponstyl',
#  'typhum': 'typhim',
#  'helicobactère': 'helicobacter',
#  'levocétirizine': 'levocetirizine',
#  'panthoprazole': 'pantoprazole',
#  'lutenil': 'lutenyl',
#  'holgyome': 'holgyeme',
#  'phaéva': 'phaeva',
#  'hémoclar': 'hemoclar',
#  'boostrixterra': 'boostrixtetra',
#  'gardasile': 'gardasil',
#  'effeor': 'effexor',
#  'granion': 'granions',
#  'vertrige': 'vectrine',
#  'endrocure': 'androcur',
#  'cefpodoxine': 'cefpodoxime',
#  'lonten': 'lonoten',
#  'ibuprophene': 'ibuprofene',
#  'létrozole': 'letrozole',
#  'zoély': 'zoely',
#  'nasocort': 'nasacort',
#  'skénan': 'skenan',
#  'levthyroxine': 'levothyroxine',
#  'betaméthasone': 'betamethasone',
#  'minidri': 'minidril',
#  'mitélase': 'mytelase',
#  'trinardiol': 'trinordiol',
#  'tétravac': 'tetravac',
#  'silecea': 'silicea',
#  'minazol': 'monazol',
#  'prothuiaden': 'prothiaden',
#  'tinordiol': 'trinordiol',
#  'luysanxia': 'lysanxia',
#  'milepertuis': 'millepertuis',
#  'uvédose': 'uvedose',
#  'gestodène': 'gestodene',
#  'surgestonne': 'surgestone',
#  'jaminelle': 'jasminelle',
#  'terginan': 'tergynan',
#  'norofloxacine': 'norfloxacine',
#  'hypérium': 'hyperium',
#  'ludoz': 'lodoz',
#  'médrol': 'medrol',
#  'micoster': 'mycoster',
#  'noctram': 'noctran',
#  'ténormine': 'tenormine',
#  'effecor': 'effexor',
#  'minrena': 'mirena',
#  'hélicidine': 'helicidine',
#  'norelevo': 'norlevo',
#  'duphastons': 'duphaston',
#  'leloo': 'leeloo',
#  'aripiprazol': 'aripiprazole',
#  'orgamétril': 'orgametril',
#  'leprozol': 'letrozole',
#  'microvla': 'microval',
#  'creatine': 'covatine',
#  'cyprotèrone': 'cyproterone',
#  'multibolic': 'multibic',
#  'omeprazol': 'omeprazole',
#  'cepodoxime': 'cefpodoxime',
#  'ignata': 'ignatia',
#  'efferlgan': 'efferalgan',
#  'monazo': 'monazol',
#  'calcaréa': 'calcarea',
#  'cortrancyl': 'cortancyl',
#  'lovénox': 'lovenox',
#  'lamictale': 'lamictal',
#  'theralith': 'teralithe',
#  'mlillepertuis': 'millepertuis',
#  'ceterizine': 'cetirizine',
#  'micycline': 'minocycline',
#  'infranrix': 'infanrix',
#  'ketoderme': 'ketoderm',
#  'lithoderm': 'lithioderm',
#  'chammilla': 'chamomilla',
#  'provame': 'provames',
#  'muriacum': 'muriaticum',
#  'soprolol': 'bisoprolol',
#  'daphalgan': 'dafalgan',
#  'tujeo': 'toujeo',
#  'primpera': 'primperan',
#  'mébéverine': 'mebeverine',
#  'valdonxan': 'valdoxan',
#  'vasorbal': 'vasobral',
#  'zyprex': 'zyprexa',
#  'monotest': 'monosept',
#  'andocur': 'androcur',
#  'protegés': 'protelos',
#  'endotélon': 'endotelon',
#  'mépronizine': 'mepronizine',
#  'prozas': 'prozac',
#  'rhinofluimicil': 'rhinofluimucil',
#  'cardenciel': 'cardensiel',
#  'milleperthuis': 'millepertuis',
#  'rivortil': 'rivotril',
#  'oxomémazine': 'oxomemazine',
#  'zyma': 'zymad',
#  'millerpertuis': 'millepertuis',
#  'quétiapin': 'quetiapine',
#  'lysensia': 'lysanxia',
#  'sertalia': 'smectalia',
#  'nourrison': 'normison',
#  'stederil': 'stediril',
#  'evapar': 'evepar',
#  'roxytromycine': 'roxithromycine',
#  'trophygil': 'trophigil',
#  'trophigill': 'trophigil',
#  'tridnordiol': 'trinordiol',
#  'nocerton': 'nocertone',
#  'engérix': 'engerix',
#  'mienesse': 'minesse',
#  'caffea': 'coffea',
#  'zirtec': 'zyrtec',
#  'florygynal': 'florgynal',
#  'feldène': 'feldene',
#  'perlodel': 'parlodel',
#  'oeuphytose': 'euphytose',
#  'chamomilia': 'chamomilla',
#  'nomégestrol': 'nomegestrol',
#  'effizin': 'effizinc',
#  'tétralysal': 'tetralysal',
#  'soluprede': 'solupred',
#  'harpagopytum': 'harpagophytum',
#  'coaaprovel': 'coaprovel',
#  'décapeptyl': 'decapeptyl',
#  'lacmital': 'lamictal',
#  'arpagophytum': 'harpagophytum',
#  'paraxetine': 'paroxetine',
#  'metfomine': 'metformine',
#  'rodogil': 'rodogyl',
#  'dopalgic': 'topalgic',
#  'ethynilestradiol': 'ethinylestradiol',
#  'minese': 'minesse',
#  'cymblalta': 'cymbalta',
#  'exeplion': 'xeplion',
#  'trynordiol': 'trinordiol',
#  'colpotrophin': 'colpotrophine',
#  'hypéricum': 'hypericum',
#  'differin': 'differine',
#  'birodrogyl': 'birodogyl',
#  'amiodorane': 'amiodarone',
#  'cémaflavone': 'cemaflavone',
#  'defalgan': 'dafalgan',
#  'weroquel': 'xeroquel',
#  'bisprolol': 'bisoprolol',
#  'synéedil': 'synedil',
#  'anxieter': 'anxietum',
#  'chlomadinone': 'chlormadinone',
#  'cafeiné': 'cafeine',
#  'tranxènes': 'tranxene',
#  'desorel': 'desobel',
#  'follique': 'folique',
#  'célestamine': 'celestamine',
#  'lisopaine': 'lidocaine',
#  'dolirhum': 'dolirhume',
#  'dupahaston': 'duphaston',
#  'thyrosine': 'thyroxine',
#  'beclospi': 'beclospin',
#  'pulmicor': 'pulmicort',
#  'surgeston': 'surgestone',
#  'eméthotrexate': 'methotrexate',
#  'luteny': 'lutenyl',
#  'témestat': 'temesta',
#  'purinéthol': 'purinethol',
#  'picroval': 'microval',
#  'pantoprazol': 'pantoprazole',
#  'leelou': 'leeloo',
#  'allergenes': 'stallergenes',
#  'mnidril': 'minidril',
#  'diazepan': 'diazepam',
#  'metformin': 'metformine',
#  'monazole': 'monazol',
#  'gynergène': 'gynergene',
#  'seroplexe': 'seroplex',
#  'saltrate': 'caltrate',
#  'gyné': 'gyno',
#  'dafalgans': 'dafalgan',
#  'rispéral': 'risperdal',
#  'phamatex': 'pharmatex',
#  'pevary': 'pevaryl',
#  'sollian': 'solian',
#  'léponex': 'leponex',
#  'diprostène': 'diprostene',
#  'mabthéra': 'mabthera',
#  'cymbaltale': 'cymbalta',
#  'serotonine': 'levotonine',
#  'econzazole': 'econazole',
#  'ciali': 'cialis',
#  'levitr': 'levitra',
#  'cylcleane': 'cycleane',
#  'séresta': 'seresta',
#  'abilfy': 'abilify',
#  'profenide': 'profenid',
#  'nozdaz': 'nordaz',
#  'ciprofloxacin': 'ciprofloxacine',
#  'malox': 'maalox',
#  'mnaelle': 'menaelle',
#  'alvesc': 'alvesco',
#  'tanxene': 'tranxene',
#  'tardiferon': 'tardyferon',
#  'valériana': 'valeriana',
#  'sédaspir': 'sedaspir',
#  'rophylac': 'rhophylac',
#  'depakot': 'depakote',
#  'millpertuis': 'millepertuis',
#  'météospasmyl': 'meteospasmyl',
#  'trinordio': 'trinordiol',
#  'pririx': 'priorix',
#  'meliodia': 'melodia',
#  'ceresta': 'seresta',
#  'béconase': 'beconase',
#  'estréva': 'estreva',
#  'déstiner': 'dostinex'}

# %%
import pandas as pd
import numpy as np
import re

XTrain = pd.read_csv('../../data/staging_data/clean_input_train.csv', sep=';')

def applyFixMap(text, fixMap):
    for word, fixedWord in fixMap.items():
        text = re.sub(r"([^a-zA-Z0-9éèàôî]|^)" + word + "([^a-zA-Z0-9éèàôî]{1})", r"\g<1>" + fixedWord + "\g<2>", text)
    return text    
        
def fixText(text):
    result = applyFixMap(text, drugFixMap)
    result = applyFixMap(result, ingredientFixMap)
    result = applyFixMap(result, generalFixMap)
    if result != text:
        print("text = " + text + "\nfix  = " + result + "\n--------------------------------------------------------\n")
    return result

XTrain['fixed_question'] = XTrain['question'].map(lambda x : fixText(x))
# Out:
# text = prend trinordiol fin première plaquette première fois copain. pilule donc bien efficace dès debut douleur poitrine, impression ils peu grossi ossi plus, mal bas ventr,e dois minkiété simplemen, periode dadaptation
# fix  = prend trinordiol fin première plaquette première fois copain. pilule donc bien efficace dès debut douleur poitrine, impression ils peu grossi ossi plus, mal bas venir,e dois minkiété simplement, periode dadaptation
# --------------------------------------------------------
#
# text = sous antiobiotique depuis bientot semaine chopée sais quoi nénétte, gratte,est superficiel démenge point, lié antibiotique
# fix  = sous antibiotique depuis bientot semaine chope sais quoi nénétte, gratte,est superficiel démenge point, lié antibiotique
# --------------------------------------------------------
#
# text = vaccins dtpe hépatire ils possible pendant grossesse
# fix  = vaccins dtpa hépatire ils possible pendant grossesse
# --------------------------------------------------------
#
# text = quand termine plaquette peut avoir raports sexuels
# fix  = quand termine plaquette peut avoir rapports sexuels
# --------------------------------------------------------
#
# text = pilule trimordiol fais grossir
# fix  = pilule trinordiol fais grossir
# --------------------------------------------------------
#
# text = bonjour, depuis presque sous effexor.on prescrit xanax cas crise angoisse car fait 3.mais voila depuis jours angoissée matin soir cela sans raison apparente.je peux presque plus rien avaler tellement nouée alors habitude mange comme vache.la moindre chose faire semble insurmontable provoque malaises..je sais plus quoi faire.je prends xanax jour alors medecin prescrit crises.malgré xanax mega angoissée non stoptout entourage remarqué collègues croient enceinte.ai peur devenir completemment agoraphobe.de plus medecin vacances sais meme passer xanax dangereux.savez combien temps peut durer type crise ?quels risques vois psychlogue depuis premiere crise donc presque an. merci lumieres..
# fix  = bonjour, depuis presque sous effexor.on prescrit xanax cas crise angoisse car fait 3.mais voila depuis jours angoissée matin soir cela sans raison apparente.je peux presque plus rien avaler tellement nouée alors habitude mange comme vache.la moindre chose faire semble insurmontable provoque malaises..je sais plus quoi faire.je prends xanax jour alors medecin prescrit crises.malgré xanax mega angoissée non stoptout entourage remarqué collègues croient enceinte.ai peur devenir completement agoraphobe.de plus medecin vacances sais meme passer xanax dangereux.savez combien temps peut durer type crise ?quels risques vois psychologue depuis premiere crise donc presque an. merci lumieres..
# --------------------------------------------------------
#
# text = sensée prendre mg, hier, pris 300. après avoir pris, chaque fois point endormir, jentendais plein voix venaient partout possible hallucinations irrégularité prise traitement
# fix  = sensée prendre mg, hier, pris 300. après avoir pris, chaque fois point endormir, entendais plein voix venaient partout possible hallucinations irrégularité prise traitement
# --------------------------------------------------------
#
# text = euphytose urtile anxiété
# fix  = euphytose utile anxiété
# --------------------------------------------------------
#
# text = medecin spécialiste gastro préscrit lansoprazole. médecin traitant préscit olmetec hypertension, depuis qiue prends ensemble réaction forme. petits points rouges très demengeant ambetant apparus quisse droite. arreté olmetec points encore partis après jours.. faire prendre
# fix  = medecin spécialiste gastro prescrit lansoprazole. médecin traitant préscit olmetec hypertension, depuis qiue prends ensemble réaction forme. petits points rouges très demengeant ambetant apparus puisse droite. arreté olmetec points encore partis après jours.. faire prendre
# --------------------------------------------------------
#
# text = risque grossese multiple vec clomid risque fil
# fix  = risque grosses multiple vec clomid risque fil
# --------------------------------------------------------
#
# text = aimerais connaitre zones exactes application estrev 0,1 gel
# fix  = aimerais connaitre zones exactes application estreva 0,1 gel
# --------------------------------------------------------
#
# text = mère oeudèmes pieds cheville plante pieds prescrire amlor ténoretic. combien temps avant cela partent
# fix  = mère oeudèmes pieds cheville plante pieds prescrire amlor tenoretic. combien temps avant cela partent
# --------------------------------------------------------
#
# text = stérogyl seulement adut
# fix  = sterogyl seulement adut
# --------------------------------------------------------
#
# text = bonjour, train prendre pillule ppelle daily gé. probleme sein toujours gonflés fait mal. medecin prescris jasminelle parait possible avoir saignement prennant quoi sert alors sein vont redevenir normaux parce uqe fait vraiment mal.. merci beaucoup
# fix  = bonjour, train prendre pillule appelle daily gé. probleme sein toujours gonflés fait mal. medecin prescris jasminelle parait possible avoir saignement prennant quoi sert alors sein vont redevenir normaux parce uqe fait vraiment mal.. merci beaucoup
# --------------------------------------------------------
#
# text = prenais pilule ludéal depuis près ans, récemment changée leeloo aujourhui symptômes nervosité, dépression, graisse abdominal nausées. pensez tout
# fix  = prenais pilule ludéal depuis près ans, récemment changée leeloo aujourdhui symptômes nervosité, dépression, graisse abdominal nausées. pensez tout
# --------------------------------------------------------
#
# text = bonjour, réveillée dimanche matin urticaire jambes peu bras.. allée voir médecin hier, déduit allergie stresam arrêté traitement dès dimanche matin prescrit poralamine. pris hier soir levant matin, présent urticaire décolleté bras mains. bien moins important jambes quand même! inquiète normal urticaire continue monter malgré poralamine dois craindre oedème quincke merci
# fix  = bonjour, réveillée dimanche matin urticaire jambes peu bras.. allée voir médecin hier, déduit allergie stresam arrêté traitement dès dimanche matin prescrit polaramine. pris hier soir levant matin, présent urticaire décolleté bras mains. bien moins important jambes quand même! inquiète normal urticaire continue monter malgré polaramine dois craindre oedème quincke merci
# --------------------------------------------------------
#
# text = voudrai savoir bétaserc, serc lectil molécule
# fix  = voudrai savoir betaserc, serc lectil molécule
# --------------------------------------------------------
#
# text = aimerais bien faire cure charbon vegetale. parait chabon absorbe tout medicamment anule donc efficacite meme pilule!! aimerais savoir cela vrai
# fix  = aimerais bien faire cure charbon vegetale. parait chabon absorbe tout medicaments angle donc efficacite meme pilule!! aimerais savoir cela vrai
# --------------------------------------------------------
#
# text = quart heure après avoir prix granules,du gluconate cuivre gouttes sillice colloïdale, palpitations sent mal,
# fix  = quart heure après avoir prix granules,du gluconate cuivre gouttes silice colloïdale, palpitations sent mal,
# --------------------------------------------------------
#
# text = peut prescrire dapis stick boiron femme enceinte
# fix  = peut prescrire apis stick boiron femme enceinte
# --------------------------------------------------------
#
# text = surdosage tricelest quel danger
# fix  = surdosage tricilest quel danger
# --------------------------------------------------------
#
# text = utilisé elavil, naxproxen petites doses problèmes dos. celebrex beaucoup spasme haut dos, entre côtes. problème dos dégénéré problèmes anxiété prends moment rivotril soir couché desyrel aussi coucheé. toujours courbatures, bien sûr passe facilement levée, crois médicaments, certitude. faire
# fix  = utilisé elavil, naproxene petites doses problèmes dos. celebrex beaucoup spasme haut dos, entre côtes. problème dos dégénéré problèmes anxiété prends moment rivotril soir couché desyrel aussi coucher. toujours courbatures, bien sûr passe facilement levée, crois médicaments, certitude. faire
# --------------------------------------------------------
# text = prend varnoline moins générique appelle desogestrel/ethinilestradiol. pharmacie redonné générique comme dab composition tout. boite design fabricant même. dois inquiéter
# fix  = prend varnoline moins générique appelle desogestrel/ethinylestradiol. pharmacie redonné générique comme dab composition tout. boite design fabricant même. dois inquiéter
# --------------------------------------------------------
#
# text = magnesia phosphorica reg très douleureuses
# fix  = magnesia phosphoricum reg très douleureuses
# --------------------------------------------------------
#
# text = prends pilule triafémi. quand oublie comprimé triphasique, passe comme monophasique. veux dire, différents dosages, peut enchaîner plaquettes cas oubli dernière semaine enchaîne, seulement comprimés dernière couleur toute plaquette
# fix  = prends pilule triafemi. quand oublie comprimé triphasique, passe comme monophasique. veux dire, différents dosages, peut enchaîner plaquettes cas oubli dernière semaine enchaîne, seulement comprimés dernière couleur toute plaquette
# --------------------------------------------------------
#
# text = lisanxia trop problème sevrage
# fix  = lysanxia trop problème sevrage
# --------------------------------------------------------
#
# text = bonjour, actuellemnt sous seroplex mg. ateinte agoraphobie assez severe ainsi trouble panique depersonalisation.je traitement depuis plus mois aucunes ameliorations toujours aussi paniqué eloigner domicile..et quand domicile mieux peur panique être seule,peur nuit tombe etc.. vis enfer.mon generaliste dis augumenter seroplex fais peur.. pensez
# fix  = bonjour, actuellemnt sous seroplex mg. atteinte agoraphobie assez severe ainsi trouble panique depersonalisation.je traitement depuis plus mois aucunes ameliorations toujours aussi paniqué eloigner domicile..et quand domicile mieux peur panique être seule,peur nuit tombe etc.. vis enfer.mon generaliste dis augmenter seroplex fais peur.. pensez
# --------------------------------------------------------
#
# text = cycléane mycose
# fix  = cycleane mycose
# --------------------------------------------------------
#
# text = sertaline joue libido
# fix  = sertraline joue libido
# --------------------------------------------------------
#
# text = argile, aloe veroa, utiliser parties intimes
# fix  = argile, aloe verra, utiliser parties intimes
# --------------------------------------------------------
#
# text = souvent prescriptions nebcine, célestene, gentamicine, solumedrol, toutes sous formes injectab prescrites ensemble nébulisation toutes hors amm voie aérosol, cela testé après laboratoires, faire
# fix  = souvent prescriptions nebcine, celestene, gentamicine, solumedrol, toutes sous formes injectab prescrites ensemble nébulisation toutes hors amm voie aérosol, cela testé après laboratoires, faire
# --------------------------------------------------------
#
# text = bonjour, sous séropram atarax depuis mois, vais mieux concernant attaques panique angoisses parcontre mal dormir surtout crises rires, partout rue, chez impression devenir débile ris rien meme toute seule devant écran
# fix  = bonjour, sous seropram atarax depuis mois, vais mieux concernant attaques panique angoisses parcontre mal dormir surtout crises rires, partout rue, chez impression devenir débile ris rien meme toute seule devant écran
# --------------------------------------------------------
#
# text = prenais orgametil maintenant prends surgestone. changement pendant premier mois, oublié prendre pilule, prise après. ensuite saignements pendant jours, très légers trouvé règ bizarre, fait test grossesse négatifs. chances enceinte
# fix  = prenais orgametril maintenant prends surgestone. changement pendant premier mois, oublié prendre pilule, prise après. ensuite saignements pendant jours, très légers trouvé règ bizarre, fait test grossesse négatifs. chances enceinte
# --------------------------------------------------------
#
# text = quelle alternative méningitec cas rupture
# fix  = quelle alternative meningitec cas rupture
# --------------------------------------------------------
#
# text = tres mal tete donc pris upfen habitude prends doliprane apres avoir pris rendu compte date peremption 02/2006 inquiete peu pensez grave
# fix  = tres mal tete donc pris upfen habitude prends doliprane apres avoir pris rendu compte date perception 02/2006 inquiete peu pensez grave
# --------------------------------------------------------
#
# text = enceintre vogalib
# fix  = enceinte vogalib
# --------------------------------------------------------
#
# text = sterilet cuivre acné
# fix  = sterilene cuivre acné
# --------------------------------------------------------
#
# text = dois éviter certains aliments kardefic peur efficacité varie
# fix  = dois éviter certains aliments kardegic peur efficacité varie
# --------------------------------------------------------
#
# text = sous cérazette depuis mois mnt, depuis semaine environ pertes blanches bcp plus abondantes habitude, dois inquieter
# fix  = sous cerazette depuis mois mnt, depuis semaine environ pertes blanches bcp plus abondantes habitude, dois inquieter
# --------------------------------------------------------
#
# text = eczema suite prise extranaze, dois faire
# fix  = eczema suite prise extranase, dois faire
# --------------------------------------------------------
#
# text = gynéco demandé faire vaccin boostrix diphtérie, tétanos, cocqueluche enceinte semaines. pose donc question dangereux futur bébé
# fix  = gynéco demandé faire vaccin boostrix diphtérie, tétanos, coqueluche enceinte semaines. pose donc question dangereux futur bébé
# --------------------------------------------------------
#
# text = diu cuive disponible planning familiale
# fix  = diu cuire disponible planning familiale
# --------------------------------------------------------
#
# text = bisoprolol cristers bisoprolol hémifumarate peut bien substituer cardensiel bisoprolol fumarate
# fix  = bisoprolol cristers bisoprolol mifumarate peut bien substituer cardensiel bisoprolol fumarate
# --------------------------------------------------------
#
# text = carrence fer, quel traitement
# fix  = carence fer, quel traitement
# --------------------------------------------------------
#
# text = desolee faire chiee monde dite cerazette peu faire avoir eruption cutanee corps apres mois prise vue dermato dit alergie lessive gel douche savon autre fais mois dure creme fais rien gratte corps ventre bras sous seins entre cuisse comme roseole fais gratte idee car peu plus drole tout merci encore desolee
# fix  = desolee faire chien monde dite cerazette peu faire avoir eruption cutanee corps apres mois prise vue dermato dit allergie lessive gel douche savon autre fais mois dure creme fais rien gratte corps ventre bras sous seins entre cuisse comme roseole fais gratte idee car peu plus drole tout merci encore desolee
# --------------------------------------------------------
#
# text = veratran apnee someil
# fix  = veratran annee someil
# --------------------------------------------------------
#
# text = depuis pris pillule jasminelle quelques mois petites taches sang marron sans gravité. aujourhui saignements comme début règ assez léger. sais faut fasse.
# fix  = depuis pris pillule jasminelle quelques mois petites taches sang marron sans gravité. aujourdhui saignements comme début règ assez léger. sais faut fasse.
# --------------------------------------------------------
#
# text = prend minidrill due oublier comprimer repris. voulais savoir aret mardi comme habitude prend comprimes
# fix  = prend minidril due oublier comprimer repris. voulais savoir aret mardi comme habitude prend comprimes
# --------------------------------------------------------
#
# text = enchaînement plaquettes adépal reprise
# fix  = enchaînement plaquettes adepal reprise
# --------------------------------------------------------
#
# text = effexor seresta avocardil/jr
# fix  = effexor seresta avlocardyl/jr
# --------------------------------------------------------
#
# text = femme utilise belara depuis mois vient anoncer douleurs sein sens presence petite corps fait mal. pouvez dire peux venir pillu belara
# fix  = femme utilise belara depuis mois vient annoncer douleurs sein sens presence petite corps fait mal. pouvez dire peux venir pillu belara
# --------------------------------------------------------
# text = termine plaquette désobel dimanche soir. vais avoir règ quelques jours après, dire jeudi.. rapport sexuels ami, pendant cette période quelques jours, tout protégée
# fix  = termine plaquette desobel dimanche soir. vais avoir règ quelques jours après, dire jeudi.. rapport sexuels ami, pendant cette période quelques jours, tout protégée
# --------------------------------------------------------
#
# text = fait hier vaccin celui gardazil, soir possible boive alcool... pensez cela dangereux
# fix  = fait hier vaccin celui gardasil, soir possible boive alcool... pensez cela dangereux
# --------------------------------------------------------
#
# text = voila depuis environ smaines mal seins pertes blanches picotemments bas ventre.pensez ceci etre signes grossesse prends stediril comme pillule!
# fix  = voila depuis environ semaines mal seins pertes blanches picotements bas ventre.pensez ceci etre signes grossesse prends stediril comme pillule!
# --------------------------------------------------------
#
# text = bonjour, voici souci: arreté diane mai, donc règ 17.. devais donc reprendre 21. medecin fais passer pilule microdosée type minesse commencé prendre mai. question est: sachant èpas pris comprimés temps ingérer: combien temps protègée dois prendre toute plaquette comprimés merci avance.
# fix  = bonjour, voici souci: arreté diane mai, donc règ 17.. devais donc reprendre 21. medecin fais passer pilule microcosme type minesse commencé prendre mai. question est: sachant èpas pris comprimés temps ingérer: combien temps protègée dois prendre toute plaquette comprimés merci avance.
# --------------------------------------------------------
#
# text = puis procurer alvocardyl sans ordonnance
# fix  = puis procurer avlocardyl sans ordonnance
# --------------------------------------------------------
#
# text = prends tolexine depuis jours constate toujours ovulé alors cycle normalement cyc très réguliers. cet antibio peut être origine retard psychologique
# fix  = prends tolexine depuis jours constate toujours ovule alors cycle normalement cyc très réguliers. cet antibio peut être origine retard psychologique
# --------------------------------------------------------
#
# text = triafermi bien mini pillule,
# fix  = triafemi bien mini pillule,
# --------------------------------------------------------
#
# text = prends stinox depuis années maintenant endors tars normal
# fix  = prends stilnox depuis années maintenant endors tars normal
# --------------------------------------------------------
#
# text = acheter tramadol zaldiar ultram ixprim contramal topalgic zamudol supeudol oxycontin methadone morphine oxycodone vicodin oxynorm sans ordonnance ligne france internet
# fix  = acheter tramadol zaldiar ultra ixprim contramal topalgic zamudol supeudol oxycontin methadone morphine oxycodone vicodin oxynorm sans ordonnance ligne france internet
# --------------------------------------------------------
#
# text = bonjour monde! voilà pri duphaston, comprimés faire venir règ car causes strees exams déréglé. après dernier cachet duphastone règ ensuite commencé prendre trinordiol jusque plaquette termine règ arrêtées!! normal contre quand commencé plaquette trinordiol tout rentré ordre saignement. sinon autre question: risque avoir difficultés avoir enfant prend pilule pendant enfant sachant encore grossesse
# fix  = bonjour monde! voilà pri duphaston, comprimés faire venir règ car causes street exams déréglé. après dernier cachet duphaston règ ensuite commencé prendre trinordiol jusque plaquette termine règ arrêtées!! normal contre quand commencé plaquette trinordiol tout rentré ordre saignement. sinon autre question: risque avoir difficultés avoir enfant prend pilule pendant enfant sachant encore grossesse
# --------------------------------------------------------
#
# text = gygy donné pillule daily prise jours apres retrait sterilet mirena. arrivée fin plaquette, reg durant arret repris normalement deuxieme plaquette, rien regles, ovulation. dois faire
# fix  = gygy donné pillule daily prise jours apres retrait sterilene mirena. arrivée fin plaquette, reg durant arret repris normalement deuxieme plaquette, rien regles, ovulation. dois faire
# --------------------------------------------------------
#
# text = deuxieme semaine prise pillule oublie jours durant lequel rapports non protegé, quand apperçu repris prise pillule comme rien était..et denouveau saignement jours cette fois ci.je viens terminer plaquette regle aujourhui comme rien etait passer, risque grossesse
# fix  = deuxieme semaine prise pillule oublie jours durant lequel rapports non protegé, quand apperçu repris prise pillule comme rien était..et denouveau saignement jours cette fois ci.je viens terminer plaquette regle aujourdhui comme rien etait passer, risque grossesse
# --------------------------------------------------------
#
# text = quelque tres angoisée generale, aconit peut aider
# fix  = quelque tres angoisse generale, aconit peut aider
# --------------------------------------------------------
#
# text = detoxat comment métabolisé
# fix  = deroxat comment métabolisé
# --------------------------------------------------------
#
# text = nouvelle homeo demande laisser tomber tous produits homeopathique seule produit netrouve pharmacie: naja 200 quelque connait
# fix  = nouvelle homeo demande laisser tomber tous produits homeopathique seule produit retrouve pharmacie: naja 200 quelque connait
# --------------------------------------------------------
#
# text = sous yaz. règ terminées semaine mas tjrs légères pertes marrons spottings quoi réalité
# fix  = sous yaz. règ terminées semaine mas tjrs légères pertes marrons sporting quoi réalité
# --------------------------------------------------------
#
# text = vaccin prévenar réchauffé inefficace plus risqué
# fix  = vaccin prevenar réchauffé inefficace plus risqué
# --------------------------------------------------------
#
# text = enceinte semaines, demangeaisons niveau vulve. demandais pouvais utilisee creme gyno daktarin
# fix  = enceinte semaines, démangeaisons niveau vulve. demandais pouvais utilisee creme gyno daktarin
# --------------------------------------------------------
#
# text = diabétique insulino dépendant. médecin presrit vaccin antiténanique repevax. püis fair injection
# fix  = diabétique insulino dépendant. médecin prescrit vaccin antiténanique repevax. püis fair injection
# --------------------------------------------------------
#
# text = arrêté cycléane ans attends règ pouvoir reprendre. voudrais savoir combien coûtent plaquettes maintenant
# fix  = arrêté cycleane ans attends règ pouvoir reprendre. voudrais savoir combien coûtent plaquettes maintenant
# --------------------------------------------------------
#
# text = cycléane fait grossir
# fix  = cycleane fait grossir
# --------------------------------------------------------
#
# text = partir combien temps après arrêt anovulant menstruations reviennent
# fix  = partir combien temps après arrêt annulant menstruations reviennent
# --------------------------------------------------------
#
# text = bonjour voilà sous pilule optidtil depuis quelque mois mois derniers oubli jours. jai fais test grossesse tous négatifs voilà soir ème jours cyc devrais avoir règ dimanche rendu compte échangés hier dernier comprimés jaune comprimés placebo. soir donc pris comprimés jaune. risque grossesse
# fix  = bonjour voilà sous pilule optidril depuis quelque mois mois derniers oubli jours. jai fais test grossesse tous négatifs voilà soir ème jours cyc devrais avoir règ dimanche rendu compte échangés hier dernier comprimés jaune comprimés placebo. soir donc pris comprimés jaune. risque grossesse
# --------------------------------------------------------
#
# text = mis eme patch evra mois hier depuis perte marront foncé. voudrai aussi savoir pourrais reduire effet patch
# fix  = mis eme patch evra mois hier depuis perte marrant foncé. voudrai aussi savoir pourrais reduire effet patch
# --------------------------------------------------------
#
# text = vais changer contracetif, voulu savoir quelque connaiser nuvaring quels probleme rencontrez
# fix  = vais changer contraceptif, voulu savoir quelque connais nuvaring quels probleme rencontrez
# --------------------------------------------------------
#
# text = sous traitement, commencé tranquilisants musculaires, aucun effet, prend maintenant stresam, stilnox atarax. mari supporte prennne médicaments. donc arrêter traitements temps pilule. aujourhui, dors mal très peu. règ signe simplement retard arrêt brutal
# fix  = sous traitement, commencé tranquilisants musculaires, aucun effet, prend maintenant stresam, stilnox atarax. mari supporte prenne médicaments. donc arrêter traitements temps pilule. aujourdhui, dors mal très peu. règ signe simplement retard arrêt brutal
# --------------------------------------------------------
# text = fils actuellement traité zeclar mg/ml solution buvable ressent fortes douleurs ventre. possible associer débridat zeclar
# fix  = fils actuellement traité zeclar mg/ml solution buvable ressent fortes douleurs ventre. possible associer debridat zeclar
# --------------------------------------------------------
#
# text = cas échec traitement azithromycine doxycycline chlamidiae faire
# fix  = cas échec traitement azithromycine doxycycline chlamydia faire
# --------------------------------------------------------
#
# text = prise cérazette mois, déréglée..normal
# fix  = prise cerazette mois, déréglée..normal
# --------------------------------------------------------
#
# text = grand pere fait vaccine contre grippe jours depuis cata.. tremblements poussees fievre etc medecins savent effet secondaire vaccin
# fix  = grand pere fait vaccine contre grippe jours depuis cata.. tremblements pousses fievre etc medecins savent effet secondaire vaccin
# --------------------------------------------------------
#
# text = prends jasminelle, oubliée. mois première fois aujourhui rendu compte saignement bien rouge alors eme jour plaquette. quoi cela pourrait etre lié
# fix  = prends jasminelle, oubliée. mois première fois aujourdhui rendu compte saignement bien rouge alors eme jour plaquette. quoi cela pourrait etre lié
# --------------------------------------------------------
#
# text = bonjour tous, voila, explique soucis. repris ere fois mois depuis années, pilule donc jour debut saignements quelques gouttes, pris debut regles, plus arrivées jours avance. plus saignement juste goutte journée..et cette donc prise vertige.. normalement reg tres abondantes, cycle regulier. comme debut pilule, reg naturels, donc pourquoi, saigne plus pourquoi vertiges pilule prends minidril merci aide, car psychote peu..
# fix  = bonjour tous, voila, explique soucis. repris ere fois mois depuis années, pilule donc jour debut saignements quelques gouttes, pris debut regles, plus arrivées jours avance. plus saignement juste goutte journée..et cette donc prise vertige.. normalement reg tres abondantes, cycle regulier. comme debut pilule, reg naturels, donc pourquoi, saigne plus pourquoi vertiges pilule prends minidril merci aide, car psychose peu..
# --------------------------------------------------------
#
# text = peut associer arnigel huile essentielle anti inflammatoire eucal citr, gaulthérie..
# fix  = peut associer arnigel huile essentielle anti inflammatoire eucal titr, gaulthérie..
# --------------------------------------------------------
#
# text = sous minidril depuis mois, début règ matin ème jour pendant mois, puis bout moment devenu matin ème jour aujourhui, dire deuxième jour arrêt, pertes marrons.. comme tâche sang. normal dois aller consulter
# fix  = sous minidril depuis mois, début règ matin ème jour pendant mois, puis bout moment devenu matin ème jour aujourdhui, dire deuxième jour arrêt, pertes marrons.. comme tâche sang. normal dois aller consulter
# --------------------------------------------------------
#
# text = commence optimisette novembre 2015 depuis commence eme boite fevrier eme plaquette horreur! frissons toute journee. faire
# fix  = commence optimizette novembre 2015 depuis commence eme boite fevrier eme plaquette horreur! frissons toute journee. faire
# --------------------------------------------------------
#
# text = libido zéro sous déroxat, normal
# fix  = libido zéro sous deroxat, normal
# --------------------------------------------------------
#
# text = viens lire parcourant infos stérilet cuivre spotof pouvait diminuer siagnements entre règles.. remboursé
# fix  = viens lire parcourant infos stérilet cuivre spotof pouvait diminuer saignements entre règles.. remboursé
# --------------------------------------------------------
#
# text = psychiatre donc prescrit déroxat puis mg. problème ans inquiète beaucoup rapport liste interminable effets indésirables. réellement risque
# fix  = psychiatre donc prescrit deroxat puis mg. problème ans inquiète beaucoup rapport liste interminable effets indésirables. réellement risque
# --------------------------------------------------------
#
# text = bonjour, espere poster bon endroit. voilà problème, prend pillule yaz depuis quelques mois, aucun oublie prend heure fixe aucun vomissements, depuis mercredi dernier nausée vraiment persistantes tous jours, très mal ventre. rien changé alimentation. ans déjà tombée enceinte fois, première suite seul malheureux claquage préservatifs, deuxième sous pillule daily septembre dernier. dernière ivg extremment désagréable sous médicaments. retrouve peu pret mêmes symptomes précédantes fois. rêg arrivent avant semaine demi eventualité énième ivg enchante absolument pas. voudrais savoir fait être tombée enceinte sous pillule pouvait causer problèmes bébé peux faire prise sang immediatement non dois arreter pilule attendant merci message édité ethpo 20/03/2010 18:44:12
# fix  = bonjour, espere poster bon endroit. voilà problème, prend pillule yaz depuis quelques mois, aucun oublie prend heure fixe aucun vomissements, depuis mercredi dernier nausée vraiment persistantes tous jours, très mal ventre. rien changé alimentation. ans déjà tombée enceinte fois, première suite seul malheureux claquage préservatifs, deuxième sous pillule daily septembre dernier. dernière ivg extremement désagréable sous médicaments. retrouve peu pret mêmes symptomes précédantes fois. rêg arrivent avant semaine demi eventualité énième ivg enchante absolument pas. voudrais savoir fait être tombée enceinte sous pillule pouvait causer problèmes bébé peux faire prise sang immediatement non dois arreter pilule attendant merci message édité ethpo 20/03/2010 18:44:12
# --------------------------------------------------------
#
# text = vaccin gardasi retiré marché
# fix  = vaccin gardasil retiré marché
# --------------------------------------------------------
#
# text = lisanxia agit bien sans trop effet indésirable
# fix  = lysanxia agit bien sans trop effet indésirable
# --------------------------------------------------------
#
# text = efféralgant dangereux insuffisance hépatique
# fix  = efferalgan dangereux insuffisance hépatique
# --------------------------------------------------------
#
# text = bonjour, fait moins deux ans ancien homéopathe prescrit gelsemiuim sempervirens troub digestif savait lié anxiété autre bref.. cet homéopathie rien servit régler problèmes disgestions, continuais malgré être très dérangé bref. coup petit tube comme neuf, rest plein granule date limite 2010, peux donc utiliser pbs angoisses, sauf plus ordonnance sais plus comment prendre, pouvez aider enfait aimerais savoir quand faut prendre jour angoisse fois journée terminé arrête prendre veut dire traitement duré jour faut prenne veille angoisse ?car souvent angoisse avance quelque chose, faut prenne semaine entière avant angoisse svp aidez sais tout comment faire vendredi samedi justement deux journée très angoissantes..
# fix  = bonjour, fait moins deux ans ancien homéopathe prescrit gelsemium sempervirens troub digestif savait lié anxiété autre bref.. cet homéopathie rien servit régler problèmes digestion, continuais malgré être très dérangé bref. coup petit tube comme neuf, rest plein granule date limite 2010, peux donc utiliser pbs angoisses, sauf plus ordonnance sais plus comment prendre, pouvez aider enfait aimerais savoir quand faut prendre jour angoisse fois journée terminé arrête prendre veut dire traitement duré jour faut prenne veille angoisse ?car souvent angoisse avance quelque chose, faut prenne semaine entière avant angoisse svp aidez sais tout comment faire vendredi samedi justement deux journée très angoissantes..
# --------------------------------------------------------
#
# text = peut utiliiser nuraving ovu
# fix  = peut utiliser nuvaring ovu
# --------------------------------------------------------
#
# text = séropram peut aider réduire boulimies
# fix  = seropram peut aider réduire boulimies
# --------------------------------------------------------
#
# text = arrêté traitement dépamide mois demi malgré sport régime sévère, vois changement balance.. certaines parmi combien temps fallu retrouver poids normal
# fix  = arrêté traitement depamide mois demi malgré sport régime sévère, vois changement balance.. certaines parmi combien temps fallu retrouver poids normal
# --------------------------------------------------------
#
# text = enceinte mois, prend bicarbonate soude brulûres estomac, fallait surtout utiliser pendant grossesse.. infos dessus
# fix  = enceinte mois, prend bicarbonate soude brulures estomac, fallait surtout utiliser pendant grossesse.. infos dessus
# --------------------------------------------------------
# text = tite louloute mois doit faire vacciner jeudi prevenar. sais vaccination contre cocceluche effets indésirab 1/3 cas fièvre.. faut donne suppo paracétamol avant prévention peut être homéopathie
# fix  = tite louloute mois doit faire vacciner jeudi prevenar. sais vaccination contre coqueluche effets indésirab 1/3 cas fièvre.. faut donne suppo paracétamol avant prévention peut être homéopathie
# --------------------------------------------------------
#
# text = fortes douleurs médecin mise sous codéine: quand prends flushs sensation picotement nez gorge déjà entendu parler genre effets indésirab
# fix  = fortes douleurs médecin mise sous codéine: quand prends flashs sensation picotement nez gorge déjà entendu parler genre effets indésirab
# --------------------------------------------------------
#
# text = lévothyrox effets secondaires
# fix  = levothyrox effets secondaires
# --------------------------------------------------------
#
# text = hier soir rendue compte oublié pilule veille. comme conseillé jamais prendre pilu pris une. notice indique prendre comprimé oublié dois faire puisje prendre journée aujourdui
# fix  = hier soir rendue compte oublié pilule veille. comme conseillé jamais prendre pilu pris une. notice indique prendre comprimé oublié dois faire puisse prendre journée aujourdui
# --------------------------------------------------------
#
# text = prescrit neuroléptique xeroquel 100 pourriez renseigner pris poids médicament
# fix  = prescrit neuroleptiques xeroquel 100 pourriez renseigner pris poids médicament
# --------------------------------------------------------
#
# text = risques prend humoxal déturgylone pendant grossesse
# fix  = risques prend humoxal deturgylone pendant grossesse
# --------------------------------------------------------
#
# text = fait vaccin gerdazil premier environ depuis hier jai sorte plaque sous peau tres douloureuze endroit fait vaccin quelque pourrais dire doit consulter
# fix  = fait vaccin gardasil premier environ depuis hier jai sorte plaque sous peau tres douloureuse endroit fait vaccin quelque pourrais dire doit consulter
# --------------------------------------------------------
#
# text = strésam entraine douleurs thoraciques
# fix  = stresam entraine douleurs thoraciques
# --------------------------------------------------------
#
# text = pilule chlormadinone générique lutéran connait
# fix  = pilule chlormadinone générique luteran connait
# --------------------------------------------------------
#
# text = prenant minesse depuis plus ans, peau plus plus sèche autres soucis. aussi commencé avoir spottings fréquemment derniers temps. viens donc supposer minesse convient plus. sûrement temps lors prochaine visite gynéco changer pilule. seulement possible
# fix  = prenant minesse depuis plus ans, peau plus plus sèche autres soucis. aussi commencé avoir sporting fréquemment derniers temps. viens donc supposer minesse convient plus. sûrement temps lors prochaine visite gynéco changer pilule. seulement possible
# --------------------------------------------------------
#
# text = sous cérazette matin viens constater petits saignements, normal
# fix  = sous cerazette matin viens constater petits saignements, normal
# --------------------------------------------------------
#
# text = sous deroxat, constemment palpitations, mal proitrine, essouflée moindre effort mal partout muscles.
# fix  = sous deroxat, constemment palpitations, mal prostine, essouffle moindre effort mal partout muscles.
# --------------------------------------------------------
#
# text = prends voltaréne épines calcanéennes souci tendon achille depuis seulement jours, semble moins mal, normal
# fix  = prends voltarene épines calcanéennes souci tendon achille depuis seulement jours, semble moins mal, normal
# --------------------------------------------------------
#
# text = gelsenium arsenic opium
# fix  = gelsemium arsenic opium
# --------------------------------------------------------
#
# text = puis croquer spasfon lyoc accélérer absorption
# fix  = puis croquer spasfon lyo accélérer absorption
# --------------------------------------------------------
#
# text = prend adepal deja enchainer deux derniere plaquette peux enchainer troisieme fait soir fait crac crac preservatif protégé encore comprimé hier protege encore soir
# fix  = prend adepal deja enchainer deux derniere plaquette peux enchainer troisieme fait soir fait crac crac préservatif protégé encore comprimé hier protege encore soir
# --------------------------------------------------------
#
# text = repris mercilon octobre, soir oublié, prise alors normalemnt prendre veille vers rapport non protégé matin nouveau oublié pilule soir, reprise risque tombe enceinte
# fix  = repris mercilon octobre, soir oublié, prise alors normalement prendre veille vers rapport non protégé matin nouveau oublié pilule soir, reprise risque tombe enceinte
# --------------------------------------------------------
#
# text = prends depuis deux jours nouvelle pillule jasminelle donc attendu premier jour reg commencer plaquette dès premier comprimé règ arretées..je demandais etait normal
# fix  = prends depuis deux jours nouvelle pillule jasminelle donc attendu premier jour reg commencer plaquette dès premier comprimé règ arretes..je demandais etait normal
# --------------------------------------------------------
#
# text = vient commencer traitement fille l`inhalateur symbicort. quel danger auquel exposee dose medicament n`est scrupulesement respectee
# fix  = vient commencer traitement fille l`inhalateur symbicort. quel danger auquel exposee dose medicament n`est scrupuleusement respectee
# --------------------------------------------------------
#
# text = seroquel disparition sang
# fix  = xeroquel disparition sang
# --------------------------------------------------------
#
# text = combien temps faut seroquel fasse effet
# fix  = combien temps faut xeroquel fasse effet
# --------------------------------------------------------
#
# text = peux prendre traitement mynocicline pendant été. vais donc faire cure zinc, pris marque naturland. que, ceux pris, remarqué poussée acné dès prise cachet
# fix  = peux prendre traitement minocycline pendant été. vais donc faire cure zinc, pris marque natulan. que, ceux pris, remarqué poussée acné dès prise cachet
# --------------------------------------------------------
#
# text = cérazette fait grossir nouveau règ
# fix  = cerazette fait grossir nouveau règ
# --------------------------------------------------------
#
# text = bonjour, qestion prend pilule ludeal savoir peux prendre plaqettes pilule ainsi suite merci bisoux message édité alyna 28/07/2009 19:17:33
# fix  = bonjour, qestion prend pilule ludeal savoir peux prendre plaquettes pilule ainsi suite merci bisoux message édité alina 28/07/2009 19:17:33
# --------------------------------------------------------
#
# text = copinette prenait pillule trinordiol heures retard. semaine derniere, reg norma arretées normalement. voila avant hier coulée sang apparue, rien hier. seulement, cette nuit capote laché demande risques pas..
# fix  = clopinettes prenait pillule trinordiol heures retard. semaine derniere, reg norma arretes normalement. voila avant hier coulée sang apparue, rien hier. seulement, cette nuit capote laché demande risques pas..
# --------------------------------------------------------
#
# text = pharmacien souhaite savoir partir quel âge peut utiliser vogalène lyoc 7,mg chez enfant
# fix  = pharmacien souhaite savoir partir quel âge peut utiliser vogalene lyo 7,mg chez enfant
# --------------------------------------------------------
#
# text = bonjour gygy posé stérilet 380 début juillet aout règle normale rien sauf migraine carabiné normal avoir prise dolyprane pendant jours moment ovulation
# fix  = bonjour gygy posé stérilet 380 début juillet aout règle normale rien sauf migraine larabine normal avoir prise doliprane pendant jours moment ovulation
# --------------------------------------------------------
#
# text = prends cerrazette oublié première fois cette semaine, reprise après. dois protéger
# fix  = prends cerazette oublié première fois cette semaine, reprise après. dois protéger
# --------------------------------------------------------
#
# text = actuellement cérazette souhaiterai changer contraception. cérazette seule pillule peux utiliser fait anomalie sanguine plus ovaire. cherche savoir autre contraception autorisée implant,..
# fix  = actuellement cerazette souhaiterai changer contraception. cerazette seule pillule peux utiliser fait anomalie sanguine plus ovaire. cherche savoir autre contraception autorisée implant,..
# --------------------------------------------------------
# text = téralithe long terme.. danger
# fix  = teralithe long terme.. danger
# --------------------------------------------------------
#
# text = cytotek obligatoire pose stérilet
# fix  = cytotec obligatoire pose stérilet
# --------------------------------------------------------
#
# text = ludeale pertes marrons
# fix  = ludeal pertes marrons
# --------------------------------------------------------
#
# text = femmes ,étant sous prozac, orgasmes lorsque baillaient. cela déjà arrivé quelque ici
# fix  = femmes ,étant sous prozac, orgasmes lorsque brillaient. cela déjà arrivé quelque ici
# --------------------------------------------------------
#
# text = sous androcur provames depuis maintenant ans. depuis quelques mois, paupieres brulent.. qque symptome suite prise androcur
# fix  = sous androcur provames depuis maintenant ans. depuis quelques mois, papiers brulent.. qque symptome suite prise androcur
# --------------------------------------------------------
#
# text = commencé pillule mercilon ère fois jour régles, ceci dit toujours rég aprés jours fatigue, maux dos surtout sens pique quand rég sortent, medecin dit dois terminer cette plaquette enchainer ensuite autre marque gracial car veux avoir prochaines rég doit normalement arreter. prenant cette ème marque enfin arreter
# fix  = commencé pillule mercilon ère fois jour régles, ceci dit toujours rég aprés jours fatigue, maux dos surtout sens pique quand rég sortent, medecin dit dois terminer cette plaquette enchainer ensuite autre marque gracias car veux avoir prochaines rég doit normalement arreter. prenant cette ème marque enfin arreter
# --------------------------------------------------------
#
# text = auré aimé savoir quelle limitte maximum niveau nombre cures magnésium peut faire année
# fix  = auré aimé savoir quelle limite maximum niveau nombre cures magnésium peut faire année
# --------------------------------------------------------
#
# text = trouve reponse internet!donc pose ici oeuphytoses nervosité troub sommeil, pris aujourdui jai prob alors crois jour plus notice dangereux
# fix  = trouve reponse internet!donc pose ici euphytose nervosité troub sommeil, pris aujourdhui jai prob alors crois jour plus notice dangereux
# --------------------------------------------------------
#
# text = seoplex cet fait grossir
# fix  = seroplex cet fait grossir
# --------------------------------------------------------
#
# text = peut prendre floradil miflonil continue
# fix  = peut prendre foradil miflonil continue
# --------------------------------------------------------
#
# text = produits contenant alverine peuvent ils provoque atteinte hépatique
# fix  = produits contenant elvorine peuvent ils provoque atteinte hépatique
# --------------------------------------------------------
#
# text = certains fruit acide comme citron lananas pamplemouss peuvent amoindrir lefficacité pilule implant
# fix  = certains fruit acide comme citron ananas pamplemousse peuvent amoindrir lefficacité pilule implant
# --------------------------------------------------------
#
# text = reg très douleureuses voudrai savoir moyen traiter homeopathie
# fix  = reg très douloureuses voudrai savoir moyen traiter homeopathie
# --------------------------------------------------------
#
# text = voulais savoir dependante ixprim tramadol quelle dose
# fix  = voulais savoir cependant ixprim tramadol quelle dose
# --------------------------------------------------------
#
# text = nizoral, antifongique kethoderm unidose crème produit quels risques
# fix  = nizoral, antifongique ketoderm unidose crème produit quels risques
# --------------------------------------------------------
#
# text = actuellement sous pilulle mercilon horreur jambes très lourdes douloureuses, tension seins, spottings, maux ventre doc prescrit adepal. avis, peux arrêter enchaîner direct adepal
# fix  = actuellement sous pilule mercilon horreur jambes très lourdes douloureuses, tension seins, sporting, maux ventre doc prescrit adepal. avis, peux arrêter enchaîner direct adepal
# --------------------------------------------------------
#
# text = gynécologue vient prescrir pillule microval. connaissez
# fix  = gynécologue vient prescrit pillule microval. connaissez
# --------------------------------------------------------
#
# text = cérazette combien coûte
# fix  = cerazette combien coûte
# --------------------------------------------------------
#
# text = voudrais savoir comment paracétamol aspirne permettent enlever douleur
# fix  = voudrais savoir comment paracétamol aspirine permettent enlever douleur
# --------------------------------------------------------
#
# text = maigrir homéopathie recommandé: ignatia amara maschus enfin urosuphon remède miracle maigrir, confirmez
# fix  = maigrir homéopathie recommandé: ignatia amara maschus enfin urosiphon remède miracle maigrir, confirmez
# --------------------------------------------------------
#
# text = cérazette prise poids
# fix  = cerazette prise poids
# --------------------------------------------------------
#
# text = bonsoir, explique souci. oubli pilule leeloo pendant jours suite. rapports durant jours oubli, rapports suivants copain mis préservatif. continué plaquette jusque fin restait jours. question savoir doit enchaîner plaquette suivante bien faire pause jours plus quelques pertes brunes depuis aujourhui.
# fix  = bonsoir, explique souci. oubli pilule leeloo pendant jours suite. rapports durant jours oubli, rapports suivants copain mis préservatif. continué plaquette jusque fin restait jours. question savoir doit enchaîner plaquette suivante bien faire pause jours plus quelques pertes brunes depuis aujourdhui.
# --------------------------------------------------------
#
# ...
# fix  = sous cerazette depuis mois maintenant, ai, moins fois semaine, fortes douleurs niveau ovaires, effets indésirab
# --------------------------------------------------------
#
# text = mnaelle générique quel médicament
# fix  = menaelle générique quel médicament
# --------------------------------------------------------
#
# text = apo hydroxyquine effets secondaires
# fix  = apo hydroxyzine effets secondaires
# --------------------------------------------------------
#
# text = pharmacienne reçoit prescription vogalène lyoc enfant ans, souhaite savoir cette forme adaptée existe autre
# fix  = pharmacienne reçoit prescription vogalene lyo enfant ans, souhaite savoir cette forme adaptée existe autre
# --------------------------------------------------------
#
# text = peux donner salbutamol ventoli alvesc bébé mois premier garçon, commencé utiliser mois.
# fix  = peux donner salbutamol ventoli alvesco bébé mois premier garçon, commencé utiliser mois.
# --------------------------------------------------------
#
# text = samedie, arrêté traitment corticoide antibiotique prescris orl pendant jours, lundi gonflement chevilles. lien
# fix  = samedie, arrêté traitment coricide antibiotique prescris orl pendant jours, lundi gonflement chevilles. lien
# --------------------------------------------------------
#
# text = arpagophitum sève bouleau effets secondaires
# fix  = harpagophytum sève bouleau effets secondaires
# --------------------------------------------------------
#
# text = dosage maximum tanxene prise
# fix  = dosage maximum tranxene prise
# --------------------------------------------------------
#
# text = eté mis sous tramadol tetrazepan, probleme toujours present, agit quasimant plus. demandais aussi médocs pouvait tous simplemant créer meme douleur combler manque
# fix  = eté mis sous tramadol tetrazepam, probleme toujours present, agit quasimant plus. demandais aussi médocs pouvait tous simplemant créer meme douleur combler manque
# --------------------------------------------------------
#
# text = strésam traite douleurs thoraciques
# fix  = stresam traite douleurs thoraciques
# --------------------------------------------------------
#
# text = prends pilule adépal oublié faire arret jours cad pris pilule pendant jours jour recommencé nouvelle plaquette. tout cycle déréglé
# fix  = prends pilule adepal oublié faire arret jours cad pris pilule pendant jours jour recommencé nouvelle plaquette. tout cycle déréglé
# --------------------------------------------------------
#
# text = patiente souhaite connaître origine présent vogalène lyoc imodium lyoc
# fix  = patiente souhaite connaître origine présent vogalene lyo imodium lyoc
# --------------------------------------------------------
#
# text = tardiferon acide folique
# fix  = tardyferon acide folique
# --------------------------------------------------------
#
# text = utilise androcure boite contient comprimés.. faut prendre comprimé faire pause jours bien prendre 21, comprimé provenant dune autre boite
# fix  = utilise androcur boite contient comprimés.. faut prendre comprimé faire pause jours bien prendre 21, comprimé provenant dune autre boite
# --------------------------------------------------------
#
# text = bonsoir, gastro semaine dernière, diarrhée vomissements. pris pilule, harmonet, tous soirs heure, pris dernières pilu plaquette semaine gastro. donc arrêt jours aujourhui recommence nouvelle plaquette, protégée soir merci réponse.
# fix  = bonsoir, gastro semaine dernière, diarrhée vomissements. pris pilule, harmonet, tous soirs heure, pris dernières pilu plaquette semaine gastro. donc arrêt jours aujourdhui recommence nouvelle plaquette, protégée soir merci réponse.
# --------------------------------------------------------
#
# text = celestène info
# fix  = celestene info
# --------------------------------------------------------
# text = puis associer millepertuis grifonia sans danger
# fix  = puis associer millepertuis agrimonia sans danger
# --------------------------------------------------------
#
# text = prend pillule minidrile depuis mois mois dernier javais reg jours aprés pose jourset pose depuis dimanche soir toujours reg normal
# fix  = prend pillule minidril depuis mois mois dernier javais reg jours aprés pose jourset pose depuis dimanche soir toujours reg normal
# --------------------------------------------------------
#
# text = cérazette saignements, arrêt
# fix  = cerazette saignements, arrêt
# --------------------------------------------------------
#
# text = sterilet mirena prise poids
# fix  = sterilene mirena prise poids
# --------------------------------------------------------
#
# text = fille coliques fréquentes bien allaitée. conseillé donner valériana ch. air être éfficace. quelque peut dire quelque chose sujet
# fix  = fille coliques fréquentes bien allaitée. conseillé donner valeriana ch. air être éfficace. quelque peut dire quelque chose sujet
# --------------------------------------------------------
#
# text = sous sédaspir aspirine, caféïne codéïne. mal post dépendance codéïne. cours risque dépendance
# fix  = sous sedaspir aspirine, caféïne codéïne. mal post dépendance codéïne. cours risque dépendance
# --------------------------------------------------------
#
# text = alprozolam zoloft
# fix  = alprazolam zoloft
# --------------------------------------------------------
#
# text = injection rophylac pendant grossesse
# fix  = injection rhophylac pendant grossesse
# --------------------------------------------------------
#
# text = prends hydorcortisone depuis mois après longue corticothérapie mois cortancyl. gonfle parfois nuit gonflement mains réveillent tant alliance serre normal
# fix  = prends hydrocortisone depuis mois après longue corticothérapie mois cortancyl. gonfle parfois nuit gonflement mains réveillent tant alliance serre normal
# --------------------------------------------------------
#
# text = depakot grossesse
# fix  = depakote grossesse
# --------------------------------------------------------
#
# text = millpertuis vraiment sans effets secondaires
# fix  = millepertuis vraiment sans effets secondaires
# --------------------------------------------------------
#
# text = efflexor 37.5
# fix  = effexor 37.5
# --------------------------------------------------------
#
# text = chikungunya affecte réunion. collègue parlé ledum palustre ch. presrit contre moustiques tropicaux aedes
# fix  = chikungunya affecte réunion. collègue parlé ledum palustre ch. prescrit contre moustiques tropicaux aedes
# --------------------------------------------------------
#
# text = vaccination meningite effets
# fix  = vaccination meningitec effets
# --------------------------------------------------------
#
# text = oublié prendre comprimé trinordio. aperçu, ceci plus après. faire
# fix  = oublié prendre comprimé trinordiol. aperçu, ceci plus après. faire
# --------------------------------------------------------
#
# text = curacné, pensez vous, meme apres fait test, organisme peut subir dégat déces plus tot, cancer foie, etc
# fix  = curacne, pensez vous, meme apres fait test, organisme peut subir dégat déces plus tot, cancer foie, etc
# --------------------------------------------------------
#
# text = meliodia encore marché
# fix  = melodia encore marché
# --------------------------------------------------------
#
# text = pillule cérazette ==} quasiment arrêt règ
# fix  = pillule cerazette ==} quasiment arrêt règ
# --------------------------------------------------------
#
# text = sous pillule depuis age ans. depuis sous carlin avant etais sous trinordyol. effet pillule moins amoindri ''cycl' sexuel tout moins envie
# fix  = sous pillule depuis age ans. depuis sous carlin avant etais sous trinordiol. effet pillule moins amoindri ''cycl' sexuel tout moins envie
# --------------------------------------------------------
#
# text = jsuis enceinte semaines tout temps malade blulure estomac nausées permanence, sens faible fatigué permanence. peux pendre homeopathie ?ou peut etre tisanes
# fix  = jsuis enceinte semaines tout temps malade blulure estomac nausées permanence, sens faible fatigué permanence. peux pendre homéopathie ?ou peut etre tisanes
# --------------------------------------------------------
#
# text = voulais savoir déroxat augmentait appétit
# fix  = voulais savoir deroxat augmentait appétit
# --------------------------------------------------------
#
# text = souffre acne, conseiler roacutane. combien temps faire effets
# fix  = souffre acne, conseiler roaccutane. combien temps faire effets
# --------------------------------------------------------
#
# text = ceresta: cest quoi sert
# fix  = seresta: cest quoi sert
# --------------------------------------------------------
#
# text = cycléane composition lutéran
# fix  = cycleane composition lutéran
# --------------------------------------------------------
#
# text = quelle dose stomectol prescrire
# fix  = quelle dose stromectol prescrire
# --------------------------------------------------------
#
# text = fils rappel prévenar hier, vois plaque rouge dépasser, enflée sous piqure plaque dur diamètre, dois faire
# fix  = fils rappel prevenar hier, vois plaque rouge dépasser, enflée sous piqure plaque dur diamètre, dois faire
# --------------------------------------------------------
#
# text = progesteronum ch, sais tout quelle heure prendre
# fix  = progesterone ch, sais tout quelle heure prendre
# --------------------------------------------------------
#
# text = sous traitement antibio amoxyciline, jaimerais savoir peux consommer alcool
# fix  = sous traitement antibio amoxicilline, jaimerais savoir peux consommer alcool
# --------------------------------------------------------
#
# text = remicad infliximab pris maladie crohn peut occasionner boutons urticaire
# fix  = remicade infliximab pris maladie crohn peut occasionner boutons urticaire
# --------------------------------------------------------
#
# text = prends jasminelle depuis plusieurs mois soir fin journée reg alrs habitude vendredi matin. risques
# fix  = prends jasminelle depuis plusieurs mois soir fin journée reg ars habitude vendredi matin. risques
# --------------------------------------------------------
#
# text = cérazette question
# fix  = cerazette question
# --------------------------------------------------------
#
# text = bonjour, aimerais savoir entre pris xanax pendant trimestre grossesse. pris peu presque chaque jour 1/2 comprime 0,5 peur car appris certains anxiolitiques pouvaient provoquer malformations. gyne dit valait mieux eviter ete formel sujet, simplement dit aucune etude clinique prouve risque plus, peut prendre medicament plus tard grossesse car meme prescrit lors premiere grossesse vers mois demi. aidez moi, peur avoir fait mal inconscience. plus peu mal passer petit traitement car tres anxieux nature faire connaissez medicaments peut prendre sans risque calmer merci.
# fix  = bonjour, aimerais savoir entre pris xanax pendant trimestre grossesse. pris peu presque chaque jour 1/2 comprime 0,5 peur car appris certains anxiolytiques pouvaient provoquer malformations. gyne dit valait mieux eviter ete formel sujet, simplement dit aucune etude clinique prouve risque plus, peut prendre medicament plus tard grossesse car meme prescrit lors premiere grossesse vers mois demi. aidez moi, peur avoir fait mal inconscience. plus peu mal passer petit traitement car tres anxieux nature faire connaissez medicaments peut prendre sans risque calmer merci.
# --------------------------------------------------------
#
# text = peut faire rétention eau dose minime béconase jour
# fix  = peut faire rétention eau dose minime beconase jour
# --------------------------------------------------------
#
# text = cérazette saignements, arrêt
# fix  = cerazette saignements, arrêt
# --------------------------------------------------------
#
# text = équivalent dicynone etamsylate etats unis
# fix  = équivalent dicynone tamsylate etats unis
# --------------------------------------------------------
#
# text = après arrêt estréva progestérone. passe
# fix  = après arrêt estreva progestérone. passe
# --------------------------------------------------------
#
# text = entendu parler vaccin déstiner contre gastro entérite. pourriez éclairer
# fix  = entendu parler vaccin dostinex contre gastro entérite. pourriez éclairer
# --------------------------------------------------------
#
# text = hypertendu traitement base atacand mono tildiem depuis ans, cause infection staphylocoque cutannée, medecin prescrit traitement semaine base augmentin amoxiciline clavulanate potassium gentamicine im, aimerais savoir interraction entre différents médicaments, médecin dit non, notice atacand précise faut faire attention sel potassium
# fix  = hypertendu traitement base atacand mono tildiem depuis ans, cause infection staphylocoque cutannée, medecin prescrit traitement semaine base augmentin amoxicilline clavulanate potassium gentamicine im, aimerais savoir interraction entre différents médicaments, médecin dit non, notice atacand précise faut faire attention sel potassium
# --------------------------------------------------------
# text = fais crise angoisse médecin propose équanil 400 mg. medicament calme provoque forte insommolence, fatigue, mal coeur finir insommie. normal
# fix  = fais crise angoisse médecin propose equanil 400 mg. medicament calme provoque forte insommolence, fatigue, mal coeur finir insomnie. normal
# --------------------------------------------------------
#
# text = prend deroxat depuis plusieurs semaine fait apnée someil normal
# fix  = prend deroxat depuis plusieurs semaine fait apnée soleil normal
# --------------------------------------------------------
#
# text = bexero remboursé
# fix  = bexsero remboursé
# --------------------------------------------------------
#
# text = sous anti depresseurs depuis peu plus an.ai changé molécu deux fois,avais commencé effexor,je ensuite passée prozac,et maintenant seropram celui mieux réussi. plus envie prendre traitement fait cela résoudra problèmes profonds,et pense réellement avoir besoin.je quelqun hyperanxieux très angoissé,mais dérpessive.. accord médecin,ai diminué moitié dose.sur combien temps arrêté ?syndrôme sevrage
# fix  = sous anti oppresseurs depuis peu plus an.ai changé molécu deux fois,avais commencé effexor,je ensuite passée prozac,et maintenant seropram celui mieux réussi. plus envie prendre traitement fait cela résoudra problèmes profonds,et pense réellement avoir besoin.je quelqun hyperanxieux très angoissé,mais dérpessive.. accord médecin,ai diminué moitié dose.sur combien temps arrêté ?syndrôme sevrage
# --------------------------------------------------------
#
# text = bonjour prends duphaston depuis mois mars car plus cyc depuis arret pilule janvier. retour cycle assez bizarre, jours premier deuxieme jours. pb, reg seul jour, pratiquement pas. pareil plus, depuis mars, fais deuxieme crise adolescence poussee acnée phenoménale dos decolleté quand
# fix  = bonjour prends duphaston depuis mois mars car plus cyc depuis arret pilule janvier. retour cycle assez bizarre, jours premier deuxieme jours. pb, reg seul jour, pratiquement pas. pareil plus, depuis mars, fais deuxieme crise adolescence pousser acnée phenoménale dos decolleté quand
# --------------------------------------------------------
#
# text = sterilet mirena depuis octobre 2010 toujours petites reg chaque depuis juin cyc bizarre, pertes marron temps temps reg plus courtes normal ?ou dois appeller gynéco
# fix  = sterilene mirena depuis octobre 2010 toujours petites reg chaque depuis juin cyc bizarre, pertes marron temps temps reg plus courtes normal ?ou dois appeller gynéco
# --------------------------------------------------------
#
# text = dois utiliser kétoderm gel fois semaine autre médicament alergie. problème hier ere fois utiliser kétoderm suivi instructions maintenant encore plus démengeaisons cheveux continuent encore tomber. normal
# fix  = dois utiliser ketoderm gel fois semaine autre médicament allergie. problème hier ere fois utiliser ketoderm suivi instructions maintenant encore plus démengeaisons cheveux continuent encore tomber. normal
# --------------------------------------------------------

# %%
# save the correction result
XTrain['question'] = XTrain['fixed_question']

XTrain = XTrain[['ID', 'question']]

XTrain.to_csv('../../data/staging_data/mispelling_fixed_clean_input_train.csv', index=None)
